# %% [markdown]
# # Get Article Metadata from PubMed
#
# This notebook gets metadata from PubMed using metapub python library, create Article nodes and link the TM nodes to Article nodes.
#
# ## Install METAPUB python library

# %%
pip install metapub
# Out:
# Requirement already satisfied: metapub in /Users/chenc/miniconda3/lib/python3.9/site-packages (0.5.5)
# Requirement already satisfied: setuptools in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (68.2.2)
# Requirement already satisfied: lxml in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (5.1.0)
# Requirement already satisfied: requests in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (2.31.0)
# Requirement already satisfied: eutils in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (0.6.0)
# Requirement already satisfied: habanero in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (1.2.3)
# Requirement already satisfied: tabulate in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (0.9.0)
# Requirement already satisfied: cssselect in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (1.2.0)
# Requirement already satisfied: unidecode in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (1.3.7)
# Requirement already satisfied: docopt in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (0.6.2)
# Requirement already satisfied: six in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (1.16.0)
# Requirement already satisfied: tox in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (4.11.3)
# Requirement already satisfied: pytest in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (7.4.3)
# Requirement already satisfied: coloredlogs in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (15.0.1)
# Requirement already satisfied: python-Levenshtein in /Users/chenc/miniconda3/lib/python3.9/site-packages (from metapub) (0.23.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from coloredlogs->metapub) (10.0)
# Requirement already satisfied: pytz in /Users/chenc/miniconda3/lib/python3.9/site-packages (from eutils->metapub) (2022.1)
# Requirement already satisfied: tqdm in /Users/chenc/miniconda3/lib/python3.9/site-packages (from habanero->metapub) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from requests->metapub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from requests->metapub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from requests->metapub) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from requests->metapub) (2023.11.17)
# Requirement already satisfied: iniconfig in /Users/chenc/miniconda3/lib/python3.9/site-packages (from pytest->metapub) (2.0.0)
# Requirement already satisfied: packaging in /Users/chenc/miniconda3/lib/python3.9/site-packages (from pytest->metapub) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from pytest->metapub) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from pytest->metapub) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from pytest->metapub) (2.0.1)
# Requirement already satisfied: Levenshtein==0.23.0 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from python-Levenshtein->metapub) (0.23.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.1.0 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from Levenshtein==0.23.0->python-Levenshtein->metapub) (3.5.1)
# Requirement already satisfied: cachetools>=5.3.1 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from tox->metapub) (5.3.2)
# Requirement already satisfied: chardet>=5.2 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from tox->metapub) (5.2.0)
# Requirement already satisfied: colorama>=0.4.6 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from tox->metapub) (0.4.6)
# Requirement already satisfied: filelock>=3.12.3 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from tox->metapub) (3.13.1)
# Requirement already satisfied: platformdirs>=3.10 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from tox->metapub) (3.10.0)
# Requirement already satisfied: pyproject-api>=1.6.1 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from tox->metapub) (1.6.1)
# Requirement already satisfied: virtualenv>=20.24.3 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from tox->metapub) (20.24.6)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Users/chenc/miniconda3/lib/python3.9/site-packages (from virtualenv>=20.24.3->tox->metapub) (0.3.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Libraries

# %%
#import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# import matplotlib.pyplot as plt 
# import seaborn as sns
# sns.set_style('darkgrid')
# sns.set_palette("colorblind")
# sns.set(rc={'figure.figsize':(11,6)})

import os 
import configparser
import csv
from collections import defaultdict
from metapub import PubMedFetcher
fetch = PubMedFetcher()

# %%
# install or import Neo4j GraphDataScience library
try: 
  from graphdatascience import GraphDataScience
  print('Successfully imported GraphDataScience')
except ModuleNotFoundError:
  # !pip3 install graphdatascience
  from graphdatascience import GraphDataScience
  print('installed and imported GraphDataScience')
# Out:
# Successfully imported GraphDataScience

# %% [markdown]
# # Custom Functions

# %%
# function adapted from Neo4j GDS Fraud Demo Notebook (h/t Zach B.)
def read_neo4j_properties(NEO4J_PROPERTIES_FILE: str=None) -> str:
  '''Parses Neo4j database or Aura connection details from provided .ini filepath.
  Requirements:
    configparser

  Args:
    NEO4J_PROPERTIES_FILE: path to a .ini file
  
  Returns:
    HOST: link to Neo4j or Aura host 
    USERNAME: login username
    PASSWORD: login password 

  Note: The .ini file should use the following syntax
    [NEO4J]
    PASSWORD=<password>
    USERNAME=<database name>
    HOST=<host uri>

  If no path is passed, the function will return the defaults:
    HOST = 'neo4j://localhost'
    USERNAME = 'neo4j'
    PASSWORD = 'password'
  '''

  if NEO4J_PROPERTIES_FILE is not None and os.path.exists(NEO4J_PROPERTIES_FILE):
      config = configparser.RawConfigParser()
      config.read(NEO4J_PROPERTIES_FILE)
      HOST = config['NEO4J']['HOST']
      USERNAME = config['NEO4J']['USERNAME']
      PASSWORD = config['NEO4J']['PASSWORD']
      print('Using HOST, USERNAME, PASSWORD from .ini file')
      return HOST, USERNAME, PASSWORD
  else:
      print('Could not find database properties file, using defaults:')
      HOST = 'neo4j://localhost'
      USERNAME = 'neo4j'
      PASSWORD = 'password'
      print(f'HOST: {HOST} \nUSERHAME: {USERNAME} \nPASSWORD: {PASSWORD}')
      return HOST, USERNAME, PASSWORD

# %%
# Get article journal full name using pubmed api
import requests

def get_article_journal_fullname_pubmed_api(pubmed_id):

    # Base URL for the PubMed API
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi"
    
    # Parameters for the request
    params = {
        "db": "pubmed",
        "id": pubmed_id,
        "retmode": "json",
        "resulttype": "full",
    }
    
    # Send GET request and get response
    response = requests.get(base_url, params=params)
    
    # Check for successful response
    if response.status_code == 200:
        data = response.json()
        #print(data)
        return data["result"][str(pubmed_id)]['fulljournalname']
    else:
        print(f"Error: {response.status_code}")
        return None

# %%
# Create merged dataframe for article metadata

from random import randint
from time import sleep


def get_article_metadata_df(fetch, article_ids_df):
    records = []
    #for pmid in pmids:
    for index, row in article_ids_df.iterrows():
        pmid = row['pmid']
        pmcid = row['pmcid']
        print(pmid)
        sleep(randint(1,5))
        meta =[]
        meta.append(pmid)
        meta.append(pmcid)
        article = fetch.article_by_pmid(pmid)
        meta.append(article.title)
        meta.append(article.abstract)
        meta.append(', '.join(article.authors))
        meta.append(article.year)
        meta.append(article.volume)
        meta.append(article.issue)
        journal_full_name = get_article_journal_fullname_pubmed_api(pmid)
        if journal_full_name is None:
            journal_full_name = article.journal
        print(journal_full_name)
        meta.append(journal_full_name)
        
        meta.append(article.citation)
        meta.append("https://pubmed.ncbi.nlm.nih.gov/"+str(pmid)+"/")
        
        records.append(meta)

    df = pd.DataFrame(records, columns=['PMID', 'PMCID', 'Title', 'Abstract', 'Author', 'Year', 'Volume', 'Issue', 'Journal', 'Citation', 'Link'])
    
    return df

# %% [markdown]
# # Connect to Neo4j DB
# It is recommended to store authentication credentials in a separate file and read them in to the notebook as variables. This code assumes the files are stored in a local auth directory.

# %%
# get authentication credentials from local auth file
NEO4J_PROPERTIES_FILE = 'auth/immerse_kg_auth.ini'
HOST, USERNAME, PASSWORD = read_neo4j_properties(NEO4J_PROPERTIES_FILE=NEO4J_PROPERTIES_FILE)
# Out:
# Using HOST, USERNAME, PASSWORD from .ini file

# %%
# connect to neo4j instance 
gds = GraphDataScience(HOST, auth=(USERNAME, PASSWORD), aura_ds=False)

# %%
# confirm connection with GDS version 
gds.version()
# Out:
# '2.5.0'

# %% [markdown]
# # Clean up Article nodes

# %%
# if necessary, clear out the Article nodes and relationships
gds.run_cypher('''
                MATCH (n:Article)
                DETACH DELETE n
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Get Article Metadata

# %%
# Get pmids for all TM nodes
article_ids_df = gds.run_cypher('''
                MATCH (t:TextMining)
                WHERE t.pmid is not null
                RETURN DISTINCT t.pmid as pmid, t.pmcid as pmcid
                ''')

# %%
# Get article meta data
article_meta = get_article_metadata_df(fetch, article_ids_df)
#article_meta
# Out:
# 25042542
# Biotechnology and bioengineering
# 25641927
# Biotechnology progress
# 25875452
# mAbs
# 26910040
# Applied microbiology and biotechnology
# 27559765
# mAbs
# 27752770
# Bioprocess and biosystems engineering
# 28597152
# Protein & cell
# 28921534
# Biotechnology and bioengineering
# 29511312
# Scientific reports
# 30552760
# Biotechnology and bioengineering
# 30682623
# iScience
# 31425633
# Biotechnology progress
# 31487120
# Biotechnology progress
# 31544815
# Antibodies (Basel, Switzerland)
# 32170810
# Biotechnology journal
# 32748555
# Biotechnology progress
# 33476097
# Biotechnology progress
# 33656168
# Biotechnology and bioengineering
# 33682619
# mAbs
# 33738790
# Biotechnology and bioengineering
# 33742789
# Biotechnology progress
# 33804825
# International journal of molecular sciences
# 34542245
# Biotechnology progress
# 34575094
# Life (Basel, Switzerland)
# 34935124
# Biotechnology and bioengineering
# 35087805
# Frontiers in bioengineering and biotechnology
# 35182428
# Biotechnology and bioengineering
# 35441833
# Biotechnology progress
# 35470430
# Biotechnology and bioengineering
# 35737825
# mAbs
# 37456731
# Frontiers in bioengineering and biotechnology
# 37731040
# Scientific reports
# 16609957
# Biotechnology and bioengineering
# 20159578
# Journal of bioscience and bioengineering
# 20639190
# Glycobiology
# 24326352
# Journal of bioscience and bioengineering
# 24728980
# Biotechnology and bioengineering
# 25014402
# Journal of biotechnology
# 25565276
# Biotechnology and bioengineering
# 26222761
# Biotechnology and bioengineering
# 27832969
# Methods (San Diego, Calif.)
# 27977914
# Biotechnology progress
# 28409838
# Biotechnology and bioengineering
# 28465212
# Journal of biotechnology
# 29673624
# Journal of biotechnology
# 29851298
# Biotechnology journal
# 29923054
# Biotechnology letters
# 30327978
# Biometals : an international journal on the role of metal ions in biology, biochemistry, and medicine
# 30959136
# Journal of biotechnology
# 34289087
# Biotechnology and bioengineering
# 23172735
# Biotechnology progress
# 28951949
# Applied microbiology and biotechnology
# 11150551
# Journal of immunological methods
# 25931375
# World journal of microbiology & biotechnology
# 26587969
# Biotechnology progress
# 27453130
# Biotechnology progress
# 29885096
# Biotechnology progress
# 15593097
# Biotechnology and bioengineering
# 15903239
# Biotechnology progress
# 22699308
# mAbs
# 24315529
# Journal of bioscience and bioengineering
# 24692242
# Biotechnology progress
# 24911584
# Bioengineered
# 26654938
# Journal of biotechnology
# 27943633
# Biotechnology journal
# 29704441
# Biotechnology and bioengineering
# 29913209
# Biotechnology advances
# 30088083
# Bioprocess and biosystems engineering
# 30414355
# Biotechnology progress
# 30554388
# Applied microbiology and biotechnology
# 30597531
# Biotechnology and bioengineering
# 30982137
# Bioprocess and biosystems engineering
# 31049620
# Applied microbiology and biotechnology
# 12950230
# The Biochemical journal
# 19224598
# Biotechnology progress
# 20589669
# Biotechnology and bioengineering
# 24166780
# Biotechnology journal
# 24381145
# Molecular biotechnology
# 24975601
# Biotechnology and bioengineering
# 25619381
# Biotechnology and bioengineering
# 27131894
# Journal of biotechnology
# 27273898
# Biotechnology progress
# 29314747
# Biotechnology progress
# 29457629
# Biotechnology and bioengineering
# 29719200
# Journal of biotechnology
# 30636290
# Biotechnology and bioengineering
# 35023143
# Biotechnology and bioengineering
# 37446069
# International journal of molecular sciences
# 37489835
# Biotechnology and bioengineering

# %%
# Check artilce metadata size
article_meta.shape
# Out:
# (89, 11)

# %%
# Spot checking
article_meta[['PMID', 'PMCID', 'Journal']].head()
# Out:
#        PMID       PMCID                                 Journal
# 0  25042542  PMC4282109        Biotechnology and bioengineering
# 1  25641927  PMC4492121                  Biotechnology progress
# 2  25875452  PMC4622614                                    mAbs
# 3  26910040  PMC4947490  Applied microbiology and biotechnology
# 4  27559765  PMC5098448                                    mAbs

# %%
article_meta.head(2).to_dict(orient='records')
# Out:
# [{'PMID': '25042542',
#   'PMCID': 'PMC4282109',
#   'Title': 'Use of a small molecule cell cycle inhibitor to control cell growth and improve specific productivity and product quality of recombinant proteins in CHO cell cultures.',
#   'Abstract': 'The continued need to improve therapeutic recombinant protein productivity has led to ongoing assessment of appropriate strategies in the biopharmaceutical industry to establish robust processes with optimized critical variables, that is, viable cell density (VCD) and specific productivity (product per cell, qP). Even though high VCD is a positive factor for titer, uncontrolled proliferation beyond a certain cell mass is also undesirable. To enable efficient process development to achieve consistent and predictable growth arrest while maintaining VCD, as well as improving qP, without negative impacts on product quality from clone to clone, we identified an approach that directly targets the cell cycle G1-checkpoint by selectively inhibiting the function of cyclin dependent kinases (CDK) 4/6 with a small molecule compound. Results from studies on multiple recombinant Chinese hamster ovary (CHO) cell lines demonstrate that the selective inhibitor can mediate a complete and sustained G0/G1 arrest without impacting G2/M phase. Cell proliferation is consistently and rapidly controlled in all recombinant cell lines at one concentration of this inhibitor throughout the production processes with specific productivities increased up to 110 pg/cell/day. Additionally, the product quality attributes of the mAb, with regard to high molecular weight (HMW) and glycan profile, are not negatively impacted. In fact, high mannose is decreased after treatment, which is in contrast to other established growth control methods such as reducing culture temperature. Microarray analysis showed major differences in expression of regulatory genes of the glycosylation and cell cycle signaling pathways between these different growth control methods. Overall, our observations showed that cell cycle arrest by directly targeting CDK4/6 using selective inhibitor compound can be utilized consistently and rapidly to optimize process parameters, such as cell growth, qP, and glycosylation profile in recombinant antibody production cultures.',
#   'Author': 'Du Z, Treiber D, McCarter JD, Fomina-Yadlin D, Saleem RA, McCoy RE, Zhang Y, Tharmalingam T, Leith M, Follstad BD, Dell B, Grisim B, Zupke C, Heath C, Morris AE, Reddy P',
#   'Year': '2015',
#   'Volume': '112',
#   'Issue': '1',
#   'Journal': 'Biotechnology and bioengineering',
#   'Citation': 'Du Z, et al. Use of a small molecule cell cycle inhibitor to control cell growth and improve specific productivity and product quality of recombinant proteins in CHO cell cultures. Use of a small molecule cell cycle inhibitor to control cell growth and improve specific productivity and product quality of recombinant proteins in CHO cell cultures. 2015; 112:141-55. doi: 10.1002/bit.25332',
#   'Link': 'https://pubmed.ncbi.nlm.nih.gov/25042542/'},
#  {'PMID': '25641927',
#   'PMCID': 'PMC4492121',
#   'Title': 'Chinese hamster ovary (CHO) host cell engineering to increase sialylation of recombinant therapeutic proteins by modulating sialyltransferase expression.',
#   'Abstract': 'N-Glycans of human proteins possess both α2,6- and α2,3-linked terminal sialic acid (SA). Recombinant glycoproteins produced in Chinese hamster overy (CHO) only have α2,3-linkage due to the absence of α2,6-sialyltransferase (St6gal1) expression. The Chinese hamster ST6GAL1 was successfully overexpressed using a plasmid expression vector in three recombinant immunoglobulin G (IgG)-producing CHO cell lines. The stably transfected cell lines were enriched for ST6GAL1 overexpression using FITC-Sambucus nigra (SNA) lectin that preferentially binds α2,6-linked SA. The presence of α2,6-linked SA was confirmed using a novel LTQ Linear Ion Trap Mass Spectrometry (LTQ MS) method including MSn fragmentation in the enriched ST6GAL1 Clone 27. Furthermore, the total SA (mol/mol) in IgG produced by the enriched ST6GAL1 Clone 27 increased by 2-fold compared to the control. For host cell engineering, the CHOZN(®) GS host cell line was transfected and enriched for ST6GAL1 overexpression. Single-cell clones were derived from the enriched population and selected based on FITC-SNA staining and St6gal1 expression. Two clones ("ST6GAL1 OE Clone 31 and 32") were confirmed for the presence of α2,6-linked SA in total host cell protein extracts. ST6GAL1 OE Clone 32 was subsequently used to express SAFC human IgG1. The recombinant IgG expressed in this host cell line was confirmed to have α2,6-linked SA and increased total SA content. In conclusion, overexpression of St6gal1 is sufficient to produce recombinant proteins with increased sialylation and more human-like glycoprofiles without combinatorial engineering of other sialylation pathway genes. This work represents our ongoing effort of glycoengineering in CHO host cell lines for the development of "bio-better" protein therapeutics and cell culture vaccine production.',
#   'Author': 'Lin N, Mascarenhas J, Sealover NR, George HJ, Brooks J, Kayser KJ, Gau B, Yasa I, Azadi P, Archer-Hartmann S',
#   'Year': '2015',
#   'Volume': '31',
#   'Issue': '2',
#   'Journal': 'Biotechnology progress',
#   'Citation': 'Lin N, et al. Chinese hamster ovary (CHO) host cell engineering to increase sialylation of recombinant therapeutic proteins by modulating sialyltransferase expression. Chinese hamster ovary (CHO) host cell engineering to increase sialylation of recombinant therapeutic proteins by modulating sialyltransferase expression. 2015; 31:334-46. doi: 10.1002/btpr.2038',
#   'Link': 'https://pubmed.ncbi.nlm.nih.gov/25641927/'}]

# %%
# if necessary, clear out the Article nodes and their relationships
gds.run_cypher('''
                MATCH (a:Article)
                DETACH DELETE a
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create Article nodes
gds.run_cypher('''
               UNWIND $article_meta AS node
               //CALL apoc.merge.node (["Article"], {pmid: node.PMID, pmcid: node.PMCID, title: node.Title, abstract: node.Abstract, authors: node.Author, year: toInteger(node.Year), voulme: node.Volume, issue: coalesce(node.Issue, 'None'), journal: node.Journal, citation: node.Citation, link: node.Link, impact_factor: node.ImpactFactor})
               
               CALL apoc.merge.node (["Article"], {pmid: node.PMID, pmcid: node.PMCID, title: node.Title, abstract: node.Abstract, authors: node.Author, year: toInteger(node.Year), voulme: node.Volume, issue: coalesce(node.Issue, 'None'), journal: node.Journal, citation: node.Citation, link: node.Link})
               YIELD node as n 
               RETURN n
              ''', {'article_meta': article_meta.to_dict('records')})
# Out:
#                                                                                         n
# 0   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 1   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 2   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 3   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 4   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 5   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 6   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 7   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 8   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 9   (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 10  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 11  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 12  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 13  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 14  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 15  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 16  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 17  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 18  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 19  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 20  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 21  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 22  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 23  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 24  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 25  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 26  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 27  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 28  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 29  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 30  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 31  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 32  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 33  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 34  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 35  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 36  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 37  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 38  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 39  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 40  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 41  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 42  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 43  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 44  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 45  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 46  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 47  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 48  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 49  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 50  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 51  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 52  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 53  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 54  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 55  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 56  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 57  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 58  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 59  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 60  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 61  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 62  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 63  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 64  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 65  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 66  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 67  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 68  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 69  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 70  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 71  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 72  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 73  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 74  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 75  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 76  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 77  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 78  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 79  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 80  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 81  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 82  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 83  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 84  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 85  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 86  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 87  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)
# 88  (journal, issue, citation, year, voulme, link, abstract, pmid, pmcid, title, authors)

# %%
# Remove property 'None' issue
gds.run_cypher('''
    MATCH(A:Article { issue: 'None' })
    REMOVE A.issue
    ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Link Textming nodes to articles
gds.run_cypher('''
    MATCH (a:Article), (t:TextMining)
    WHERE a.pmid = t.pmid
    MERGE (t)-[:IS_MENTIONED_IN]->(a)
    ''')
# Out:
# 2024-04-21 21:31:41 UD-Q3J7G7FQ7J-D root[35492] INFO {'severity': 'INFORMATION', 'description': 'If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (t))', 'code': 'Neo.ClientNotification.Statement.CartesianProduct', 'position': {'column': 1, 'offset': 5, 'line': 2}, 'title': 'This query builds a cartesian product between disconnected patterns.', 'category': 'PERFORMANCE'}
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Use the entities from the text mining to get the ontological concepts as the context for a given Article
context_df = gds.run_cypher('''match(n:TextMining)-[:HAS_CANONICAL_NAME]->(d:DictionaryConcept)-[:IS_INSTANCE_OF]->(o:OntologicalConcept)-[:SUB_CLASS_OF*]->(o2:OntologicalConcept)
where n.pmid is not null
with n, collect (distinct o.name) as child, collect (distinct o2.name) as ancestor
with n, child, ancestor, apoc.coll.unionAll(child, ancestor) as all
return distinct n.pmid as pmid, apoc.coll.sort(all) as context order by pmid''')

# %%
data = defaultdict(set)
# Loop through each row
for index, row in context_df.iterrows():
  #print(f"Row index: {index}")
  #print(f"PMID: {row['pmid']}, Context: {row['context']}")
  for val in row['context']:
      #print(val)
      data[row['pmid']].add(val)
merged_dict =[]
for key in data:
    #print(key, (", ").join([element for element in sorted(data[key])]))
    value = (", ").join([element for element in sorted(data[key])])
    article = {}
    article['pmid'] = key
    article['context'] = value
    merged_dict.append(article)
merged_dict
# type(merged_dict)
merged_context_df = pd.DataFrame.from_dict(merged_dict)
merged_context_df
# Out:
#         pmid  \
# 0   11150551
# 1   12950230
# 2   15593097
# 3   15903239
# 4   16609957
# 5   19224598
# 6   20159578
# 7   20589669
# 8   20639190
# 9   22699308
# 10  23172735
# 11  24166780
# 12  24315529
# 13  24326352
# 14  24692242
# 15  24728980
# 16  24911584
# 17  24975601
# 18  25014402
# 19  25042542
# 20  25565276
# 21  25619381
# 22  25641927
# 23  25875452
# 24  25931375
# 25  26222761
# 26  26587969
# 27  26654938
# 28  26910040
# 29  27131894
# 30  27273898
# 31  27453130
# 32  27559765
# 33  27752770
# 34  27832969
# 35  27943633
# 36  27977914
# 37  28409838
# 38  28465212
# 39  28597152
# 40  28921534
# 41  28951949
# 42  29314747
# 43  29457629
# 44  29511312
# 45  29673624
# 46  29704441
# 47  29719200
# 48  29851298
# 49  29885096
# 50  29913209
# 51  29923054
# 52  30088083
# 53  30327978
# 54  30414355
# 55  30552760
# 56  30554388
# 57  30597531
# 58  30636290
# 59  30682623
# 60  30959136
# 61  30982137
# 62  31049620
# 63  31425633
# 64  31487120
# 65  31544815
# 66  32170810
# 67  32748555
# 68  33476097
# 69  33656168
# 70  33682619
# 71  33738790
# 72  33742789
# 73  33804825
# 74  34289087
# 75  34542245
# 76  34575094
# 77  34935124
# 78  35023143
# 79  35087805
# 80  35182428
# 81  35441833
# 82  35470430
# 83  35737825
# 84  37446069
# 85  37456731
# 86  37489835
# 87  37731040
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        context
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                   PTM, biological process, glycosylation, metabolic pathways
# 1                                                                                                                                                                                                                                                                                                                                                                                                    carbon source, cell line, chinese hamster ovary (CHO), primary raw materials, saccharides, secondary raw materials, sugar
# 2                                                                                                                                                                                                                                                                                                                                               PTM, amino acid, biological process, carbon source, glycosylation, metabolic pathways, process outcome, product quality attributes, secondary raw materials, substrates, sugar
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                 PTM, biological process, cell line, glycosylation, metabolic pathways, primary raw materials
# 4                                                                                                                                                                                                                                                                          PTM, antibody, biological process, carbon source, cell line, cell line characteristics , genotype, glycosylation, metabolic pathways, non-fucosylated antibody, primary raw materials, raw material characteristics, secondary raw materials, sugar
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                 PTM, biological process, cell line, glycosylation, metabolic pathways, primary raw materials
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                               cell culture parameters, process parameters or process control
# 7                                                                                                                                                                                                                                                                                                                                                                                                                         PTM, biological process, glycosylation, metabolic pathways, process outcome, product quality profile
# 8                                                                                                                                                                                                                                                                                                                                                                                                                    PTM, biological process, carbon source, glycosylation, metabolic pathways, secondary raw materials, sugar
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                carbon source, secondary raw materials, sugar
# 10                                                                                                                                                                                                  PTM, biological process, cell culture parameters, cell line characteristics , genotype, glycosylation, metabolic pathways, overall titer or batch yield, process outcome, process parameters or process control, product quality attributes, raw material characteristics, vessel or process parameter or production scale
# 11                                                                                                                                                                                                                                                                                                                                                                                                   PTM, biological process, cell line, chinese hamster ovary (CHO), glycosylation, metabolic pathways, primary raw materials
# 12                                                                                                                                                                                                                                                                                                                                                                                                                          carbon source, disaccharides, process outcome, product quality attributes, secondary raw materials
# 13                                                                                                                                                                                                                                                                                                                                                                                                                     PTM, biological process, glycosylation, metabolic pathways, process outcome, product quality attributes
# 14                                                                                                                                                                                                                                                                            bioreactor conditions, carbon source, culture condition, media characteristics, process condition, process outcome, process parameters or process control, product quality profile, raw material characteristics, secondary raw materials, sugar
# 15                                                                                                                                                                                                                                                                                                                          carbon source, media characteristics, process outcome, product quality attributes, product quality profile, raw material characteristics, secondary raw materials, sugar, trace metals or minerals
# 16                                                                                                                                                                                                                                                                                                                                                    PTM, biological process, carbon source, cell line, chinese hamster ovary (CHO), glycosylation, metabolic pathways, primary raw materials, secondary raw materials, sugar
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                          cell line characteristics , genotype, raw material characteristics
# 18                                                                                                                                                                                                                                                                                                                                                                            PTM, amino acid, biological process, bioreactor conditions, glycosylation, metabolic pathways, process parameters or process control, substrates
# 19                                                                                                PTM, antibody, biological process, bioreactor conditions, carbon source, cell culture parameters, cell cycle pathway G0/G1/M/G2, cell line, cell line characteristics , flux rate, genotype, glycosylation, metabolic pathways, monoclonal antibody, primary raw materials, process outcome, process parameters or process control, product quality attributes, raw material characteristics, secondary raw materials, sugar
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                               carbon source, secondary raw materials, sugar
# 21                                                                                                                                                                                                                                                                                                                                                                                                                     PTM, biological process, glycosylation, metabolic pathways, process outcome, product quality attributes
# 22                                                                                                                                                                                                                                                                                                                                                                                                                carbon source, cell line, chinese hamster ovary (CHO), primary raw materials, secondary raw materials, sugar
# 23                                                                                                                                                                                                                                                                                                                                                                                                             PTM, acid, biological process, carbon source, glycosylation, metabolic pathways, secondary raw materials, sugar
# 24                                                                                                                                                                                                                                                                                                                                                                      PTM, biological process, carbon source, glycosylation, metabolic pathways, process outcome, product quality attributes, secondary raw materials, sugar
# 25                                                                                                                                                                                                                                                                                                                                                                         PTM, biological process, carbon source, glycosylation, metabolic pathways, process outcome, product quality profile, secondary raw materials, sugar
# 26                                                                                                                                                                                                                                                                                                                                                                                                                   PTM, biological process, carbon source, glycosylation, metabolic pathways, secondary raw materials, sugar
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                               overall titer or batch yield, process outcome
# 28                                                                                                                                                                  PTM, antibody, biological process, bioreactor conditions, carbon source, cell culture parameters, cell line, flux rate, glycosylation, media parameter or raw material, metabolic pathways, monoclonal antibody, primary raw materials, process outcome, process parameters or process control, product quality attributes, secondary raw materials, sugar
# 29                                                                                                                                                                                                                                                                                                       amino acid, carbon source, media characteristics, metabolic pathways, process outcome, product quality attributes, raw material characteristics, secondary raw materials, substrates, sugar, trace metals or minerals
# 30                                                                                                                                                                                                                                                                                                                                                                     amino acid, bioreactor conditions, carbon source, metabolic pathways, process parameters or process control, secondary raw materials, substrates, sugar
# 31                                                                                                                                                                                                                                                biological process, bioreactor conditions, carbon source, cell culture parameters, metabolic pathways, overall titer or batch yield, process outcome, process parameters or process control, secondary raw materials, sugar, vessel or process parameter or production scale
# 32                                                                                                                                PTM, antibody, biological process, bioreactor conditions, carbon source, cell line, chinese hamster ovary (CHO), glycosylation, metabolic pathways, monoclonal antibody, primary raw materials, process outcome, process parameters or process control, product quality attributes, product quality profile, secondary raw materials, sugar, vessel or process parameter or production scale
# 33                                                          PTM, acid, amino acid, antibody, biological process, bioreactor conditions, carbon source, cell culture parameters, cell line, chinese hamster ovary (CHO), flux rate, glycosylation, media characteristics, metabolic pathways, monoclonal antibody, primary raw materials, process outcome, process parameters or process control, product quality attributes, product quality profile, raw material characteristics, secondary raw materials, substrates, sugar
# 34                                                                                                                                                                                                                                                                                                                                                                                                                   PTM, biological process, carbon source, glycosylation, metabolic pathways, secondary raw materials, sugar
# 35                                                                                                                                                                                                                                                                                                                                               PTM, biological process, carbon source, cell line characteristics , genotype, glycosylation, metabolic pathways, raw material characteristics, secondary raw materials, sugar
# 36                                                                                                                                                                                                                                                                                                                                                                                  bioreactor conditions, cell culture parameters, media characteristics, process parameters or process control, raw material characteristics
# 37                                                                                                                                                                                                                       PTM, biological process, carbon source, cell culture parameters, glycosylation, media characteristics, metabolic pathways, process outcome, process parameters or process control, product quality attributes, raw material characteristics, secondary raw materials, sugar, trace metals or minerals
# 38                                                                                                                                                                                                                                                                               PTM, biological process, carbon source, cell culture parameters, cell line characteristics , genotype, glycosylation, metabolic pathways, process parameters or process control, raw material characteristics, secondary raw materials, sugar
# 39                                                                                                                                                                                                                                                                                                                                                         PTM, biological process, carbon source, glycosylation, metabolic pathways, process outcome, product quality attributes, saccharides, secondary raw materials, sugar
# 40                                                                                                                                                                                                                     bioreactor conditions, carbon source, cell line, cell line characteristics , flux rate, genotype, overall titer or batch yield, primary raw materials, process outcome, process parameters or process control, product quality attributes, raw material characteristics, secondary raw materials, sugar
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                   amino acid, carbon source, metabolic pathways, secondary raw materials, substrates, sugar
# 42                                                                                                                                                                                                                                                                                                                                                                                          PTM, biological process, glycosylation, media parameter or raw material, metabolic pathways, process parameters or process control
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                  PTM, biological process, carbon source, metabolic pathways, secondary raw materials, sugar
# 44  PTM, amino acid, antibody, biological process, bioreactor conditions, carbon source, cell culture parameters, cell line, cell nutrient, chinese hamster ovary (CHO), culture condition, disaccharides, glycosylation, media characteristics, metabolic pathways, monoclonal antibody, overall titer or batch yield, primary raw materials, process condition, process outcome, process parameters or process control, product quality attributes, raw material characteristics, secondary raw materials, substrates, sugar
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                     carbon source, process outcome, product quality profile, secondary raw materials, sugar
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                               overall titer or batch yield, process outcome
# 47                                                                                                                                                                                                                                                                                                                                                                                                                                      process parameters or process control, vessel or process parameter or production scale
# 48                                                                                                                                                                                                                                                                                                                                                                                                                                                                  PTM, biological process, glycosylation, metabolic pathways
# 49                                                                                                                                                                                                                                                                                                                                                                          PTM, biological process, glycosylation, metabolic pathways, process parameters or process control, vessel or process parameter or production scale
# 50                                                                                                                                                                                                                                                                                                                                                                                                                          metabolic pathways, nucleotide or nucleoside, process outcome, product quality profile, substrates
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                  PTM, biological process, glycosylation, metabolic pathways
# 52                                                                                                                                                                                                                                                                                                                                                                                                    PTM, biological process, bioreactor conditions, glycosylation, metabolic pathways, process parameters or process control
# 53                                                                                                                                                                                                                                                                                                                                                                                         PTM, biological process, carbon source, glycosylation, metabolic pathways, secondary raw materials, sugar, trace metals or minerals
# 54                                                                                                                                                                                                                                                                                                                                                                                                                                                                  PTM, biological process, glycosylation, metabolic pathways
# 55            PTM, antibody, biological process, carbon source, cell culture parameters, cell line, chinese hamster ovary (CHO), disaccharides, flux rate, glycosylation, media characteristics, metabolic pathways, monoclonal antibody, nitrogen sources, nucleotide or nucleoside, overall titer or batch yield, primary raw materials, process outcome, process parameters or process control, product quality profile, raw material characteristics, secondary raw materials, substrates, sugar, trace metals or minerals
# 56                                                                                                                                                                                                                                                                                                                                                                                         PTM, biological process, carbon source, glycosylation, metabolic pathways, secondary raw materials, sugar, trace metals or minerals
# 57                                                                                                                                                                                                                                                                                                                                                                                                               PTM, biological process, glycosylation, metabolic pathways, secondary raw materials, trace metals or minerals
# 58                                                                                                                                                                                                                                                                                                                                                                                                    PTM, biological process, bioreactor conditions, glycosylation, metabolic pathways, process parameters or process control
# 59                                                 PTM, acid, amino acid, antibody, biological process, carbon source, cell culture parameters, cell line, cell line characteristics , chinese hamster ovary (CHO), genotype, glycosylation, media characteristics, metabolic pathways, monoclonal antibody, nucleotide or nucleoside, primary raw materials, process parameters or process control, raw material characteristics, secondary raw materials, substrates, sugar, vessel or process parameter or production scale
# 60                                                                                                                                                                                                                                                                                                                                    bioreactor conditions, overall titer or batch yield, process outcome, process parameters or process control, product quality attributes, vessel or process parameter or production scale
# 61                                                                                                                                                                                                                                                                                                                                                                       cell line, chinese hamster ovary (CHO), primary raw materials, process parameters or process control, vessel or process parameter or production scale
# 62                                                                                                                                                                                                                                                                                                                                                                                                                                                                  PTM, biological process, glycosylation, metabolic pathways
# 63                                                                                                                                    PTM, amino acid, antibody, biological process, carbon source, cell culture parameters, glycosylation, media parameter or raw material, metabolic pathways, monoclonal antibody, process outcome, process parameters or process control, product quality attributes, product quality profile, secondary raw materials, substrates, sugar, vessel or process parameter or production scale
# 64                                                                    PTM, amino acid, biological process, carbon source, cell culture parameters, cell line, chinese hamster ovary (CHO), glycosylation, media, media characteristics, metabolic pathways, overall titer or batch yield, primary raw materials, process outcome, process parameters or process control, product quality attributes, raw material characteristics, secondary raw materials, substrates, sugar, vessel or process parameter or production scale
# 65                                                                                                                                                                                                                   PTM, biological process, carbon source, cell culture parameters, cell line, chinese hamster ovary (CHO), glycosylation, metabolic pathways, primary raw materials, process outcome, process parameters or process control, product quality profile, secondary raw materials, substitution material, sugar
# 66                                                                                                                                                                                      PTM, acid, antibody, biological process, carbon source, cell culture parameters, cell line, cellular metabolic state, chinese hamster ovary (CHO), culture condition, glycosylation, metabolic pathways, monoclonal antibody, primary raw materials, process condition, process parameters or process control, secondary raw materials
# 67                                                                                                                                                                                                  antibody, carbon source, cell culture parameters, cell line, cellular metabolic state, chinese hamster ovary (CHO), culture condition, monoclonal antibody, overall titer or batch yield, primary raw materials, process condition, process outcome, process parameters or process control, secondary raw materials, sugar
# 68                                                                                                                                                                                                                                                                                                                                                                                                                antibody, carbon source, metabolic pathways, monoclonal antibody, secondary raw materials, substrates, sugar
# 69                                                                                                                                                 PTM, amino acid, biological process, bioreactor conditions, cell culture parameters, cell line, chinese hamster ovary (CHO), flux rate, media, media characteristics, metabolic pathways, overall titer or batch yield, primary raw materials, process outcome, process parameters or process control, product quality attributes, raw material characteristics, substrates
# 70                                                                                                                                                                                                                         PTM, antibody, biological process, carbon source, cell culture parameters, glycosylation, metabolic pathways, monoclonal antibody, process outcome, process parameters or process control, product quality profile, secondary raw materials, sugar, vessel or process parameter or production scale
# 71                                                                                                                                                                                                                                                                                                   PTM, biological process, cell culture parameters, cell line, chinese hamster ovary (CHO), metabolic pathways, overall titer or batch yield, primary raw materials, process outcome, process parameters or process control
# 72                                                  PTM, antibody, biological process, cell culture parameters, cell line, chinese hamster ovary (CHO), culture condition, glycosylation, media characteristics, metabolic pathways, monoclonal antibody, overall titer or batch yield, primary raw materials, process condition, process outcome, process parameters or process control, product quality attributes, product quality profile, raw material characteristics, secondary raw materials, trace metals or minerals
# 73    PTM, antibody, biological process, bioreactor conditions, carbon source, cell culture parameters, cell cycle pathway G0/G1/M/G2, cell line, cellular metabolic state, chinese hamster ovary (CHO), culture condition, glycosylation, media characteristics, metabolic pathways, monoclonal antibody, primary raw materials, process condition, process outcome, process parameters or process control, product quality attributes, product quality profile, raw material characteristics, secondary raw materials, sugar
# 74                                                                                                                                                                                                                                                            PTM, biological process, bioreactor conditions, cellular metabolic state, culture condition, glycosylation, metabolic pathways, overall titer or batch yield, process condition, process outcome, process parameters or process control, product quality profile
# 75                                                                                                                                                                                                                                                                                                                                               acid, antibody, cell culture parameters, monoclonal antibody, process parameters or process control, secondary raw materials, vessel or process parameter or production scale
# 76                                                                                                                                                                                                             amino acid, antibody, cell culture parameters, cell line, chinese hamster ovary (CHO), media parameter or raw material, metabolic pathways, monoclonal antibody, primary raw materials, process outcome, process parameters or process control, product quality attributes, product quality profile, substrates
# 77                                                                                                                                                                                                                                                                                                                       PTM, amino acid, biological process, carbon source, cell line characteristics , genotype, glycosylation, metabolic pathways, raw material characteristics, secondary raw materials, substrates, sugar
# 78                                                                                                                                                                                                                                                                                                                                                                             PTM, biological process, carbon source, culture condition, glycosylation, metabolic pathways, process condition, secondary raw materials, sugar
# 79           PTM, antibody, biological process, bioreactor conditions, carbon source, cell culture parameters, cell line, cellular metabolic state, chinese hamster ovary (CHO), culture condition, glycosylation, media characteristics, metabolic pathways, monoclonal antibody, primary raw materials, process condition, process outcome, process parameters or process control, product quality attributes, raw material characteristics, secondary raw materials, sugar, vessel or process parameter or production scale
# 80                                                                                                                                                                                                                                                                                                                                                                                                                                                                  PTM, biological process, glycosylation, metabolic pathways
# 81                               PTM, biological process, bioreactor conditions, carbon source, cell culture parameters, cell line, chinese hamster ovary (CHO), culture condition, gases, glycosylation, media characteristics, metabolic pathways, overall titer or batch yield, primary raw materials, process condition, process outcome, process parameters or process control, product quality attributes, raw material characteristics, secondary raw materials, sugar, vessel or process parameter or production scale
# 82                                                                                                                                                                                                                                                   antibody, bioreactor conditions, carbon source, cell culture parameters, media characteristics, monoclonal antibody, process parameters or process control, raw material characteristics, secondary raw materials, sugar, vessel or process parameter or production scale
# 83                                                                                                                                                                                                                          PTM, biological process, cell culture parameters, cell line, culture condition, glycosylation, metabolic pathways, overall titer or batch yield, primary raw materials, process condition, process outcome, process parameters or process control, vessel or process parameter or production scale
# 84                                                                                                                                                                                                                                                                                                                                                                                                                     PTM, biological process, glycosylation, metabolic pathways, process outcome, product quality attributes
# 85                                                                                                                                                                                                                                                                                                   cell culture parameters, flux rate, media characteristics, process outcome, process parameters or process control, product quality profile, raw material characteristics, vessel or process parameter or production scale
# 86                                                                                                                                                                                                                                                                                                                                                                                                                                                              cellular metabolic state, culture condition, process condition
# 87                     PTM, antibody, biological process, carbon source, cell culture parameters, cell line, cell line characteristics , chinese hamster ovary (CHO), flux rate, genotype, glycosylation, media characteristics, metabolic pathways, monoclonal antibody, primary raw materials, process outcome, process parameters or process control, product quality attributes, product quality profile, raw material characteristics, secondary raw materials, serum or serum replacements, substitution material, sugar

# %%
# Create Article context
gds.run_cypher('''
               UNWIND $context_list AS cl
               MATCH (a:Article)
               WHERE a.pmid = cl.pmid
               SET a.doc_context = cl.context
               //RETURN a
              ''', {'context_list': merged_context_df.to_dict('records')})
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create contraint on Concept nodes
gds.run_cypher('''CREATE CONSTRAINT article IF NOT EXISTS FOR (a:Article) REQUIRE a.pmid IS UNIQUE''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Check existing constraints
gds.run_cypher('''SHOW CONSTRAINTS''')
# Out:
#    id                 name        type entityType         labelsOrTypes  \
# 0  11              article  UNIQUENESS       NODE             [Article]
# 1   5   dictionary_concept  UNIQUENESS       NODE   [DictionaryConcept]
# 2   2  ontological_concept  UNIQUENESS       NODE  [OntologicalConcept]
# 3   8          text_mining  UNIQUENESS       NODE          [TextMining]
#
#   properties           ownedIndex
# 0     [pmid]              article
# 1       [id]   dictionary_concept
# 2       [id]  ontological_concept
# 3       [id]          text_mining

# %%
# Create fulltext index on Article nodes
gds.run_cypher('''CREATE FULLTEXT INDEX article_search IF NOT EXISTS FOR (a:Article) ON EACH [a.title, a.abstract, a.authors, a.citation, a.journal, a.issue, a.volume, a.year]''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# exports the whole database incl. indexes as cypher statements to the provided file
gds.run_cypher('''CALL apoc.export.cypher.all('kg_export_after_load_article.cypher',{format:'cypher-shell'})''')
# Out:
#                                   file  batches  \
# 0  kg_export_after_load_article.cypher        1
#
#                               source  format  nodes  relationships  \
# 0  database: nodes(3488), rels(7373)  cypher   3488           7373
#
#    properties  time   rows  batchSize cypherStatements nodeStatements  \
# 0       48948   240  10861      20000             None           None
#
#   relationshipStatements schemaStatements cleanupStatements
# 0                   None             None              None
