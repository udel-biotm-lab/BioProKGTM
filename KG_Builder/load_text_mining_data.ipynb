# %% [markdown]
# # Load Text Mining Data

# %%
This notebook reads in the textmining results file ('data/FL_ABS_Chap.xlsx') in Excel format and convert it into a nodes file ('data/FL_ABS_Chap_Nodes.tsv') and an edges file ('data/FL_ABS_Chap_Edges.tsv') in table separated values file format for loading into Neo4j database.

# %% [markdown]
# ## Import Libraries

# %%
#import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# import matplotlib.pyplot as plt 
# import seaborn as sns
# sns.set_style('darkgrid')
# sns.set_palette("colorblind")
# sns.set(rc={'figure.figsize':(11,6)})

import os 
import configparser
import csv
import hashlib

# %%
# install or import Neo4j GraphDataScience library
try: 
  from graphdatascience import GraphDataScience
  print('Successfully imported GraphDataScience')
except ModuleNotFoundError:
  # !pip3 install graphdatascience
  from graphdatascience import GraphDataScience
  print('installed and imported GraphDataScience')
# Out:
# Successfully imported GraphDataScience

# %% [markdown]
# # Custom Functions

# %%
# function adapted from Neo4j GDS Fraud Demo Notebook (h/t Zach B.) mainly used for connecting to Neo4j database from Python
def read_neo4j_properties(NEO4J_PROPERTIES_FILE: str=None) -> str:
  '''Parses Neo4j database or Aura connection details from provided .ini filepath.
  Requirements:
    configparser

  Args:
    NEO4J_PROPERTIES_FILE: path to a .ini file
  
  Returns:
    HOST: link to Neo4j or Aura host 
    USERNAME: login username
    PASSWORD: login password 

  Note: The .ini file should use the following syntax
    [NEO4J]
    PASSWORD=<password>
    USERNAME=<database name>
    HOST=<host uri>

  If no path is passed, the function will return the defaults:
    HOST = 'neo4j://localhost'
    USERNAME = 'neo4j'
    PASSWORD = 'password'
  '''

  if NEO4J_PROPERTIES_FILE is not None and os.path.exists(NEO4J_PROPERTIES_FILE):
      config = configparser.RawConfigParser()
      config.read(NEO4J_PROPERTIES_FILE)
      HOST = config['NEO4J']['HOST']
      USERNAME = config['NEO4J']['USERNAME']
      PASSWORD = config['NEO4J']['PASSWORD']
      print('Using HOST, USERNAME, PASSWORD from .ini file')
      return HOST, USERNAME, PASSWORD
  else:
      print('Could not find database properties file, using defaults:')
      HOST = 'neo4j://localhost'
      USERNAME = 'neo4j'
      PASSWORD = 'password'
      print(f'HOST: {HOST} \nUSERHAME: {USERNAME} \nPASSWORD: {PASSWORD}')
      return HOST, USERNAME, PASSWORD

# %%
# function to convert textmining data in TSV format into Nodes and Edges in TSV format
def process_textmining_data_tsv(tm_file_path, nodes_file_path, edges_file_path):
    nodes = []
    edges = []
    with open(tm_file_path, "r", encoding="utf8") as tm_file:
        tsv_reader = csv.reader(tm_file, delimiter="\t")

        # Skip the first row, which is the header
        next(tsv_reader)

        for row in tsv_reader:
            (pmid, pmcid, trigger, arg0_np, arg0_head, arg0_base, arg0_term, arg0_type, arg0_coid, arg1_np, arg1_head, arg1_base, arg1_term, arg1_type, arg1_coid, sent_text, section, relation) = row
            #print(row)
            arg0_id_str = f"{pmid}\t{pmcid}\t{arg0_np}\t{arg0_head}\t{arg0_base}\t{arg0_type}\t{arg0_term}\t{arg0_coid}\t{section}\targ0"
            arg0_id = hashlib.md5(arg0_id_str.encode('utf-8')).hexdigest()
            arg0 = f"{arg0_id}\t{arg0_id_str}"
            
            arg1_id_str = f"{pmid}\t{pmcid}\t{arg1_np}\t{arg1_head}\t{arg1_base}\t{arg1_type}\t{arg1_term}\t{arg1_coid}\t{section}\targ1"
            arg1_id = hashlib.md5(arg1_id_str.encode('utf-8')).hexdigest()
            arg1 = f"{arg1_id}\t{arg1_id_str}"
            
            if arg0 not in nodes:
                nodes.append(arg0)
            
            if arg1 not in nodes:
                nodes.append(arg1)
                
            relation = relation.replace(" ", "_").upper()
            edge = f"{pmid}\t{pmcid}\t{arg0_id}\t{relation}\t{arg1_id}\t{trigger}\t{sent_text}\t{section}"
            
            if edge not in edges:
                edges.append(edge)
                
    tm_file.close()
    
    # open file nodes file for write
    with open(nodes_file_path, "w") as nodes_file:
        # write header
        nodes_header = f"nodeId\tpmid\tpmcid\tnp\thead\tbase\ttype\tterm\tcoid\tsection\targ_type"
        nodes_file.write(nodes_header+"\n")
        # write to file
        for chunk in nodes:
            nodes_file.write(chunk+"\n")
    nodes_file.close()
    
    # open file edges file for write
    with open(edges_file_path, "w") as edges_file:
        # write header
        edges_header = f"pmid\tpmcid\targ0_id\trelation\targ1_id\ttrigger\tsent_text\tsection"
        edges_file.write(edges_header+"\n")
        # write to file
        for chunk in edges:
            edges_file.write(chunk+"\n")
    edges_file.close()

# %%
# function to convert textmining data in Excel format into Nodes and Edges in TSV format
def process_textmining_data(tm_excel_file_path, nodes_file_path, edges_file_path):
    nodes = []
    edges = []
    df = pd.read_excel(tm_excel_file_path).fillna('')

    for index, row in df.iterrows():
        pmid = row['PMID/Chapter']
        pmcid = row['PMCID/ISBN']
        trigger = ' '.join(row['trigger'].split())
        arg0_np = ' '.join(row['arg0_np'].split())
        arg0_head = ' '.join(row['arg0_head'].split())
        arg0_base = ' '.join(row['arg0_base'].split())
        arg0_term = ' '.join(row['arg0_matched'].split())
        arg0_type = ' '.join(row['arg0_type'].split())
        arg0_coid = ' '.join(row['arg0_coid'].split())

        arg1_np = ' '.join(row['arg1_np'].split())
        arg1_head = ' '.join(row['arg1_head'].split())
        arg1_base = ' '.join(row['arg1_base'].split())
        arg1_term = ' '.join(row['arg1_matched'].split())
        arg1_type = ' '.join(row['arg1_type'].split())
        arg1_coid = ' '.join(row['arg1_coid'].split())
        
        sent_text = ' '.join(row['sent_text'].split())
        section = ' '.join(row['section'].split())
        relation = ' '.join(row['relation_type'].split())
        
        arg0_id_str = f"{pmid}\t{pmcid}\t{arg0_np}\t{arg0_head}\t{arg0_base}\t{arg0_type}\t{arg0_term}\t{arg0_coid}\t{section}\targ0"
        arg0_id = hashlib.md5(arg0_id_str.encode('utf-8')).hexdigest()
        arg0 = f"{arg0_id}\t{arg0_id_str}"
            
        arg1_id_str = f"{pmid}\t{pmcid}\t{arg1_np}\t{arg1_head}\t{arg1_base}\t{arg1_type}\t{arg1_term}\t{arg1_coid}\t{section}\targ1"
        arg1_id = hashlib.md5(arg1_id_str.encode('utf-8')).hexdigest()
        arg1 = f"{arg1_id}\t{arg1_id_str}"
            
        if arg0 not in nodes:
            nodes.append(arg0)
            
        if arg1 not in nodes:
            nodes.append(arg1)
                
        relation = relation.replace(" ", "_").upper()
        edge = f"{pmid}\t{pmcid}\t{arg0_id}\t{relation}\t{arg1_id}\t{trigger}\t{sent_text}\t{section}"
        
        if edge not in edges:
            edges.append(edge)
    
    # open file nodes file for write
    with open(nodes_file_path, "w") as nodes_file:
        # write header
        nodes_header = f"nodeId\tpmid\tpmcid\tnp\thead\tbase\ttype\tterm\tcoid\tsection\targ_type"
        nodes_file.write(nodes_header+"\n")
        # write to file
        for chunk in nodes:
            nodes_file.write(chunk+"\n")
    nodes_file.close()
    
    # open file edges file for write
    with open(edges_file_path, "w") as edges_file:
        # write header
        edges_header = f"pmid\tpmcid\targ0_id\trelation\targ1_id\ttrigger\tsent_text\tsection"
        edges_file.write(edges_header+"\n")
        # write to file
        for chunk in edges:
            edges_file.write(chunk+"\n")
    edges_file.close()

# %%
# Take cleaned textming output file and generate Nodes and Edges files in TSV format for loading into Neo4J
process_textmining_data(tm_excel_file_path='data/FL_ABS_Chap.xlsx', nodes_file_path='data/FL_ABS_Chap_Nodes.tsv', edges_file_path='data/FL_ABS_Chap_Edges.tsv')

# %% [markdown]
# # Connect to Neo4j DB
# It is recommended to store authentication credentials in a separate file and read them in to the notebook as variables. This code assumes the files are stored in a local auth directory.

# %%
# get authentication credentials from local auth file
NEO4J_PROPERTIES_FILE = 'auth/immerse_kg_auth.ini'
HOST, USERNAME, PASSWORD = read_neo4j_properties(NEO4J_PROPERTIES_FILE=NEO4J_PROPERTIES_FILE)
# Out:
# Using HOST, USERNAME, PASSWORD from .ini file

# %%
# connect to neo4j instance 
gds = GraphDataScience(HOST, auth=(USERNAME, PASSWORD), aura_ds=False)

# %%
# confirm connection with GDS version 
gds.version()
# Out:
# '2.5.0'

# %% [markdown]
# # Clean Textming Contents

# %%
# if the step of loading textmining results failed or want to reload textmining results, clearup textmining results from the databas
gds.run_cypher('''
                MATCH (n:TextMining)
                DETACH DELETE n
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Read textming data into panda dataframe

# %%
# read Nodes.tsv
nodes = pd.read_csv('data/FL_ABS_Chap_Nodes.tsv', sep='\t', header=0).fillna('NA') 
nodes.head().to_dict(orient='records')
# Out:
# [{'nodeId': 'ecd04bee9dceaef7fa4938f22aa7554f',
#   'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'np': 'a glycoprotein',
#   'head': 'glycoprotein',
#   'base': 'a glycoprotein',
#   'type': 'product',
#   'term': 'glycoprotein',
#   'coid': 'COID866322',
#   'section': 'CHAPTER 1',
#   'arg_type': 'arg0'},
#  {'nodeId': '93693ceb75f76e4812c310c1bdba7ccc',
#   'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'np': 'The glycans attached to a glycoprotein',
#   'head': 'glycans',
#   'base': 'The glycans',
#   'type': 'sugar (subset of carbon source)',
#   'term': 'glycans',
#   'coid': 'COID626759',
#   'section': 'CHAPTER 1',
#   'arg_type': 'arg1'},
#  {'nodeId': 'a5e0d84ea0572fbc2fcb951b74e75094',
#   'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'np': 'the presence of mannose 6-phosphate on the glycan of a number of lysosomal enzymes',
#   'head': 'presence',
#   'base': 'the presence',
#   'type': 'sugar (subset of carbon source)',
#   'term': 'glycan',
#   'coid': 'COID626759',
#   'section': 'CHAPTER 1',
#   'arg_type': 'arg0'},
#  {'nodeId': '46d774ee1dfba907a2391c8131f82bab',
#   'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'np': 'the protein binding to the mannose 6-phosphate receptor on cell plasma membrane for uptake, a step necessary for targeting the enzymes to lysosomes',
#   'head': 'binding',
#   'base': 'the protein binding',
#   'type': 'sugar (subset of carbon source)',
#   'term': 'mannose',
#   'coid': 'COID906305',
#   'section': 'CHAPTER 1',
#   'arg_type': 'arg1'},
#  {'nodeId': 'e0e2a67393582b28c29c16fdf0b34b25',
#   'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'np': 'The status of molecular folding, glycan composition, and even the composition of minute impurities',
#   'head': 'status',
#   'base': 'The status',
#   'type': 'sugar (subset of carbon source)',
#   'term': 'glycan',
#   'coid': 'COID626759',
#   'section': 'CHAPTER 1',
#   'arg_type': 'arg0'}]

# %%
# read Edges.tsv
edges = pd.read_csv('data/FL_ABS_Chap_Edges.tsv', sep='\t', header=0).fillna('NA') 
edges.head().to_dict(orient='records')
# Out:
# [{'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'arg0_id': 'ecd04bee9dceaef7fa4938f22aa7554f',
#   'relation': 'CORRELATED_NOT_SPECIFIED',
#   'arg1_id': '93693ceb75f76e4812c310c1bdba7ccc',
#   'trigger': 'attached',
#   'sent_text': 'The glycans attached to a glycoprotein are structurally heterogeneous.',
#   'section': 'CHAPTER 1'},
#  {'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'arg0_id': 'a5e0d84ea0572fbc2fcb951b74e75094',
#   'relation': 'CORRELATED_NOT_SPECIFIED',
#   'arg1_id': '46d774ee1dfba907a2391c8131f82bab',
#   'trigger': 'mediating',
#   'sent_text': 'For example, the presence of mannose 6-phosphate on the glycan of a number of lysosomal enzymes is critical in mediating the protein binding to the mannose 6-phosphate receptor on cell plasma membrane for uptake, a step necessary for targeting the enzymes to lysosomes.',
#   'section': 'CHAPTER 1'},
#  {'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'arg0_id': 'e0e2a67393582b28c29c16fdf0b34b25',
#   'relation': 'CORRELATED_NOT_SPECIFIED',
#   'arg1_id': '92cfcc4a044c13f8b4fb9ccd7ab2cd15',
#   'trigger': 'affect',
#   'sent_text': 'The status of molecular folding, glycan composition, and even the composition of minute impurities may affect activity and immunogenicity.',
#   'section': 'CHAPTER 1'},
#  {'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'arg0_id': '001e4f2998bbe233e8ac4ff9d2df63c6',
#   'relation': 'CORRELATED_NOT_SPECIFIED',
#   'arg1_id': '583572ca99d0191833b545cd05e0f373',
#   'trigger': 'affects',
#   'sent_text': "In some cases, the glycan structure does not directly influence the protein's biological activities but affects its pharmacokinetic behavior.",
#   'section': 'CHAPTER 1'},
#  {'pmid': 'chapter_1',
#   'pmcid': '978-1-4987-6285-4',
#   'arg0_id': 'fe68a05eafa5bcbbb17e043ebc37d00d',
#   'relation': 'CORRELATED_NOT_SPECIFIED',
#   'arg1_id': 'fa766ae504710314d07589a13690813e',
#   'trigger': 'assessed',
#   'sent_text': 'Such quality changes can only be assessed over time.',
#   'section': 'CHAPTER 1'}]

# %% [markdown]
# # Load nodes and edges

# %%
# Create contraint on TM nodes
gds.run_cypher('''CREATE CONSTRAINT text_mining IF NOT EXISTS FOR (t:TextMining) REQUIRE t.id IS UNIQUE''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# load textming results nodes
gds.run_cypher('''
               UNWIND $node_list AS node
               CALL apoc.merge.node (["TextMining"], {id: node.nodeId, doc_id: node.pmid, doc_id_type: "PMID", pmid: node.pmid, pmcid: node.pmcid, type: node.type, np: node.np, head: node.head, base: node.base, term: node.term, coid: node.coid, section: node.section, arg_type: node.arg_type})
               YIELD node as n 
               RETURN n
              ''', {'node_list': nodes.to_dict('records')})
# Out:
#                                                                                                 n
# 0     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 1     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 3     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 4     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 5     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 6     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 7     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 8     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 9     (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 10    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 11    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 12    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 13    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 14    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 15    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 16    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 17    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 18    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 19    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 20    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 21    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 22    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 23    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 24    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 25    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 26    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 27    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 28    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 29    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 30    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 31    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 32    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 33    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 34    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 35    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 36    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 37    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 38    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 39    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 40    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 41    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 42    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 43    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 44    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 45    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 46    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 47    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 48    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 49    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 50    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 51    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 52    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 53    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 54    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 55    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 56    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 57    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 58    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 59    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 60    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 61    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 62    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 63    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 64    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 65    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 66    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 67    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 68    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 69    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 70    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 71    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 72    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 73    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 74    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 75    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 76    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 77    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 78    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 79    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 80    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 81    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 82    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 83    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 84    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 85    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 86    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 87    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 88    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 89    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 90    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 91    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 92    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 93    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 94    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 95    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 96    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 97    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 98    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 99    (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 100   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 101   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 102   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 103   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 104   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 105   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 106   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 107   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 108   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 109   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 110   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 111   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 112   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 113   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 114   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 115   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 116   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 117   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 118   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 119   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 120   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 121   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 122   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 123   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 124   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 125   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 126   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 127   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 128   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 129   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 130   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 131   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 132   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 133   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 134   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 135   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 136   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 137   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 138   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 139   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 140   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 141   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 142   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 143   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 144   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 145   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 146   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 147   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 148   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 149   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 150   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 151   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 152   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 153   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 154   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 155   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 156   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 157   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 158   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 159   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 160   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 161   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 162   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 163   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 164   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 165   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 166   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 167   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 168   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 169   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 170   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 171   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 172   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 173   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 174   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 175   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 176   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 177   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 178   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 179   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 180   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 181   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 182   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 183   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 184   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 185   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 186   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 187   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 188   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 189   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 190   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 191   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 192   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 193   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 194   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 195   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 196   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 197   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 198   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 199   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 200   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 201   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 202   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 203   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 204   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 205   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 206   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 207   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 208   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 209   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 210   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 211   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 212   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 213   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 214   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 215   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 216   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 217   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 218   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 219   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 220   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 221   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 222   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 223   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 224   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 225   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 226   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 227   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 228   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 229   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 230   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 231   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 232   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 233   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 234   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 235   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 236   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 237   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 238   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 239   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 240   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 241   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 242   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 243   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 244   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 245   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 246   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 247   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 248   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 249   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 250   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 251   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 252   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 253   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 254   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 255   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 256   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 257   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 258   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 259   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 260   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 261   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 262   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 263   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 264   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 265   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 266   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 267   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 268   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 269   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 270   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 271   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 272   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 273   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 274   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 275   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 276   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 277   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 278   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 279   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 280   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 281   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 282   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 283   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 284   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 285   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 286   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 287   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 288   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 289   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 290   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 291   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 292   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 293   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 294   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 295   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 296   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 297   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 298   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 299   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 300   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 301   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 302   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 303   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 304   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 305   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 306   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 307   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 308   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 309   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 310   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 311   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 312   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 313   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 314   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 315   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 316   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 317   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 318   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 319   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 320   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 321   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 322   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 323   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 324   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 325   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 326   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 327   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 328   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 329   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 330   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 331   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 332   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 333   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 334   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 335   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 336   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 337   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 338   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 339   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 340   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 341   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 342   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 343   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 344   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 345   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 346   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 347   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 348   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 349   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 350   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 351   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 352   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 353   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 354   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 355   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 356   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 357   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 358   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 359   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 360   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 361   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 362   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 363   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 364   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 365   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 366   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 367   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 368   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 369   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 370   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 371   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 372   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 373   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 374   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 375   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 376   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 377   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 378   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 379   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 380   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 381   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 382   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 383   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 384   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 385   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 386   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 387   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 388   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 389   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 390   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 391   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 392   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 393   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 394   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 395   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 396   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 397   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 398   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 399   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 400   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 401   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 402   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 403   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 404   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 405   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 406   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 407   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 408   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 409   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 410   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 411   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 412   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 413   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 414   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 415   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 416   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 417   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 418   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 419   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 420   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 421   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 422   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 423   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 424   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 425   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 426   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 427   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 428   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 429   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 430   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 431   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 432   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 433   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 434   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 435   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 436   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 437   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 438   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 439   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 440   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 441   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 442   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 443   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 444   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 445   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 446   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 447   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 448   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 449   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 450   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 451   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 452   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 453   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 454   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 455   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 456   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 457   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 458   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 459   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 460   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 461   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 462   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 463   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 464   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 465   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 466   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 467   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 468   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 469   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 470   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 471   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 472   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 473   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 474   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 475   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 476   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 477   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 478   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 479   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 480   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 481   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 482   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 483   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 484   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 485   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 486   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 487   (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# ...
# 2532  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2533  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2534  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2535  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2536  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2537  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2538  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2539  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2540  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2541  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2542  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2543  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2544  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2545  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2546  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2547  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2548  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2549  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2550  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2551  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2552  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2553  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2554  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2555  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2556  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2557  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2558  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2559  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2560  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2561  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2562  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2563  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2564  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2565  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2566  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2567  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2568  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2569  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2570  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2571  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2572  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2573  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2574  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2575  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2576  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2577  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2578  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2579  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2580  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2581  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2582  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2583  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2584  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2585  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2586  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2587  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2588  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2589  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2590  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2591  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2592  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2593  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2594  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2595  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2596  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2597  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2598  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2599  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2600  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2601  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2602  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2603  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2604  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2605  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2606  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2607  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2608  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2609  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2610  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2611  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2612  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2613  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2614  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2615  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2616  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2617  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2618  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2619  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2620  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2621  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2622  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2623  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2624  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2625  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2626  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2627  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2628  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2629  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2630  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2631  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2632  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2633  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2634  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2635  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2636  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2637  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2638  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2639  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2640  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2641  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2642  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2643  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2644  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2645  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2646  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2647  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2648  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2649  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2650  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2651  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2652  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2653  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2654  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2655  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2656  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2657  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2658  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2659  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2660  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2661  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2662  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2663  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2664  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2665  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2666  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2667  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2668  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2669  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2670  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2671  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2672  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2673  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2674  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2675  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2676  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2677  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2678  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2679  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2680  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2681  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2682  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2683  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2684  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2685  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2686  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2687  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2688  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2689  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2690  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2691  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2692  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2693  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)
# 2694  (np, coid, section, pmid, type, doc_id, doc_id_type, arg_type, head, term, id, pmcid, base)

# %%
# Add Effector Labels
gds.run_cypher('''
                match(n:TextMining {arg_type:"arg0"}) set n:Effector
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Add Affected Labels
gds.run_cypher('''
                match(n:TextMining {arg_type:"arg1"}) set n:Affected
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# remove empty term property from TextMining nodes
gds.run_cypher('''
                match(n:TextMining { term: "NA"}) 
                remove n.term
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# remove empty type property from TextMining nodes
gds.run_cypher('''
                match(n:TextMining { type: "NA"}) 
                remove n.type
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# remove unknown type from TM nodes
gds.run_cypher('''
                match(n:TextMining { type: "NYK"}) 
                remove n.type
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# link TextMining nodes to DictionaryConcept by coid
gds.run_cypher('''
                MATCH(t:TextMining), (d:DictionaryConcept)
                WHERE  t.coid = d.id
                MERGE (t)-[:HAS_CANONICAL_NAME]->(d)
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# load TextMining reesults edges
gds.run_cypher('''
               UNWIND $edge_list AS edge
               MATCH (s)
               WHERE s.id = edge.arg0_id
               MATCH (d)
               WHERE d.id = edge.arg1_id
               CALL apoc.merge.relationship(s, edge.relation, {doc_id: edge.pmid, doc_id_type: "PMID", trigger: edge.trigger, sent_text: edge.sent_text, section: edge.section},{}, d,{}) 
               YIELD rel
               RETURN rel
              ''', {'edge_list': edges.to_dict('records')})
# Out:
#                                                      rel
# 0     (sent_text, section, trigger, doc_id, doc_id_type)
# 1     (sent_text, section, trigger, doc_id, doc_id_type)
# 2     (sent_text, section, trigger, doc_id, doc_id_type)
# 3     (sent_text, section, trigger, doc_id, doc_id_type)
# 4     (sent_text, section, trigger, doc_id, doc_id_type)
# 5     (sent_text, section, trigger, doc_id, doc_id_type)
# 6     (sent_text, section, trigger, doc_id, doc_id_type)
# 7     (sent_text, section, trigger, doc_id, doc_id_type)
# 8     (sent_text, section, trigger, doc_id, doc_id_type)
# 9     (sent_text, section, trigger, doc_id, doc_id_type)
# 10    (sent_text, section, trigger, doc_id, doc_id_type)
# 11    (sent_text, section, trigger, doc_id, doc_id_type)
# 12    (sent_text, section, trigger, doc_id, doc_id_type)
# 13    (sent_text, section, trigger, doc_id, doc_id_type)
# 14    (sent_text, section, trigger, doc_id, doc_id_type)
# 15    (sent_text, section, trigger, doc_id, doc_id_type)
# 16    (sent_text, section, trigger, doc_id, doc_id_type)
# 17    (sent_text, section, trigger, doc_id, doc_id_type)
# 18    (sent_text, section, trigger, doc_id, doc_id_type)
# 19    (sent_text, section, trigger, doc_id, doc_id_type)
# 20    (sent_text, section, trigger, doc_id, doc_id_type)
# 21    (sent_text, section, trigger, doc_id, doc_id_type)
# 22    (sent_text, section, trigger, doc_id, doc_id_type)
# 23    (sent_text, section, trigger, doc_id, doc_id_type)
# 24    (sent_text, section, trigger, doc_id, doc_id_type)
# 25    (sent_text, section, trigger, doc_id, doc_id_type)
# 26    (sent_text, section, trigger, doc_id, doc_id_type)
# 27    (sent_text, section, trigger, doc_id, doc_id_type)
# 28    (sent_text, section, trigger, doc_id, doc_id_type)
# 29    (sent_text, section, trigger, doc_id, doc_id_type)
# 30    (sent_text, section, trigger, doc_id, doc_id_type)
# 31    (sent_text, section, trigger, doc_id, doc_id_type)
# 32    (sent_text, section, trigger, doc_id, doc_id_type)
# 33    (sent_text, section, trigger, doc_id, doc_id_type)
# 34    (sent_text, section, trigger, doc_id, doc_id_type)
# 35    (sent_text, section, trigger, doc_id, doc_id_type)
# 36    (sent_text, section, trigger, doc_id, doc_id_type)
# 37    (sent_text, section, trigger, doc_id, doc_id_type)
# 38    (sent_text, section, trigger, doc_id, doc_id_type)
# 39    (sent_text, section, trigger, doc_id, doc_id_type)
# 40    (sent_text, section, trigger, doc_id, doc_id_type)
# 41    (sent_text, section, trigger, doc_id, doc_id_type)
# 42    (sent_text, section, trigger, doc_id, doc_id_type)
# 43    (sent_text, section, trigger, doc_id, doc_id_type)
# 44    (sent_text, section, trigger, doc_id, doc_id_type)
# 45    (sent_text, section, trigger, doc_id, doc_id_type)
# 46    (sent_text, section, trigger, doc_id, doc_id_type)
# 47    (sent_text, section, trigger, doc_id, doc_id_type)
# 48    (sent_text, section, trigger, doc_id, doc_id_type)
# 49    (sent_text, section, trigger, doc_id, doc_id_type)
# 50    (sent_text, section, trigger, doc_id, doc_id_type)
# 51    (sent_text, section, trigger, doc_id, doc_id_type)
# 52    (sent_text, section, trigger, doc_id, doc_id_type)
# 53    (sent_text, section, trigger, doc_id, doc_id_type)
# 54    (sent_text, section, trigger, doc_id, doc_id_type)
# 55    (sent_text, section, trigger, doc_id, doc_id_type)
# 56    (sent_text, section, trigger, doc_id, doc_id_type)
# 57    (sent_text, section, trigger, doc_id, doc_id_type)
# 58    (sent_text, section, trigger, doc_id, doc_id_type)
# 59    (sent_text, section, trigger, doc_id, doc_id_type)
# 60    (sent_text, section, trigger, doc_id, doc_id_type)
# 61    (sent_text, section, trigger, doc_id, doc_id_type)
# 62    (sent_text, section, trigger, doc_id, doc_id_type)
# 63    (sent_text, section, trigger, doc_id, doc_id_type)
# 64    (sent_text, section, trigger, doc_id, doc_id_type)
# 65    (sent_text, section, trigger, doc_id, doc_id_type)
# 66    (sent_text, section, trigger, doc_id, doc_id_type)
# 67    (sent_text, section, trigger, doc_id, doc_id_type)
# 68    (sent_text, section, trigger, doc_id, doc_id_type)
# 69    (sent_text, section, trigger, doc_id, doc_id_type)
# 70    (sent_text, section, trigger, doc_id, doc_id_type)
# 71    (sent_text, section, trigger, doc_id, doc_id_type)
# 72    (sent_text, section, trigger, doc_id, doc_id_type)
# 73    (sent_text, section, trigger, doc_id, doc_id_type)
# 74    (sent_text, section, trigger, doc_id, doc_id_type)
# 75    (sent_text, section, trigger, doc_id, doc_id_type)
# 76    (sent_text, section, trigger, doc_id, doc_id_type)
# 77    (sent_text, section, trigger, doc_id, doc_id_type)
# 78    (sent_text, section, trigger, doc_id, doc_id_type)
# 79    (sent_text, section, trigger, doc_id, doc_id_type)
# 80    (sent_text, section, trigger, doc_id, doc_id_type)
# 81    (sent_text, section, trigger, doc_id, doc_id_type)
# 82    (sent_text, section, trigger, doc_id, doc_id_type)
# 83    (sent_text, section, trigger, doc_id, doc_id_type)
# 84    (sent_text, section, trigger, doc_id, doc_id_type)
# 85    (sent_text, section, trigger, doc_id, doc_id_type)
# 86    (sent_text, section, trigger, doc_id, doc_id_type)
# 87    (sent_text, section, trigger, doc_id, doc_id_type)
# 88    (sent_text, section, trigger, doc_id, doc_id_type)
# 89    (sent_text, section, trigger, doc_id, doc_id_type)
# 90    (sent_text, section, trigger, doc_id, doc_id_type)
# 91    (sent_text, section, trigger, doc_id, doc_id_type)
# 92    (sent_text, section, trigger, doc_id, doc_id_type)
# 93    (sent_text, section, trigger, doc_id, doc_id_type)
# 94    (sent_text, section, trigger, doc_id, doc_id_type)
# 95    (sent_text, section, trigger, doc_id, doc_id_type)
# 96    (sent_text, section, trigger, doc_id, doc_id_type)
# 97    (sent_text, section, trigger, doc_id, doc_id_type)
# 98    (sent_text, section, trigger, doc_id, doc_id_type)
# 99    (sent_text, section, trigger, doc_id, doc_id_type)
# 100   (sent_text, section, trigger, doc_id, doc_id_type)
# 101   (sent_text, section, trigger, doc_id, doc_id_type)
# 102   (sent_text, section, trigger, doc_id, doc_id_type)
# 103   (sent_text, section, trigger, doc_id, doc_id_type)
# 104   (sent_text, section, trigger, doc_id, doc_id_type)
# 105   (sent_text, section, trigger, doc_id, doc_id_type)
# 106   (sent_text, section, trigger, doc_id, doc_id_type)
# 107   (sent_text, section, trigger, doc_id, doc_id_type)
# 108   (sent_text, section, trigger, doc_id, doc_id_type)
# 109   (sent_text, section, trigger, doc_id, doc_id_type)
# 110   (sent_text, section, trigger, doc_id, doc_id_type)
# 111   (sent_text, section, trigger, doc_id, doc_id_type)
# 112   (sent_text, section, trigger, doc_id, doc_id_type)
# 113   (sent_text, section, trigger, doc_id, doc_id_type)
# 114   (sent_text, section, trigger, doc_id, doc_id_type)
# 115   (sent_text, section, trigger, doc_id, doc_id_type)
# 116   (sent_text, section, trigger, doc_id, doc_id_type)
# 117   (sent_text, section, trigger, doc_id, doc_id_type)
# 118   (sent_text, section, trigger, doc_id, doc_id_type)
# 119   (sent_text, section, trigger, doc_id, doc_id_type)
# 120   (sent_text, section, trigger, doc_id, doc_id_type)
# 121   (sent_text, section, trigger, doc_id, doc_id_type)
# 122   (sent_text, section, trigger, doc_id, doc_id_type)
# 123   (sent_text, section, trigger, doc_id, doc_id_type)
# 124   (sent_text, section, trigger, doc_id, doc_id_type)
# 125   (sent_text, section, trigger, doc_id, doc_id_type)
# 126   (sent_text, section, trigger, doc_id, doc_id_type)
# 127   (sent_text, section, trigger, doc_id, doc_id_type)
# 128   (sent_text, section, trigger, doc_id, doc_id_type)
# 129   (sent_text, section, trigger, doc_id, doc_id_type)
# 130   (sent_text, section, trigger, doc_id, doc_id_type)
# 131   (sent_text, section, trigger, doc_id, doc_id_type)
# 132   (sent_text, section, trigger, doc_id, doc_id_type)
# 133   (sent_text, section, trigger, doc_id, doc_id_type)
# 134   (sent_text, section, trigger, doc_id, doc_id_type)
# 135   (sent_text, section, trigger, doc_id, doc_id_type)
# 136   (sent_text, section, trigger, doc_id, doc_id_type)
# 137   (sent_text, section, trigger, doc_id, doc_id_type)
# 138   (sent_text, section, trigger, doc_id, doc_id_type)
# 139   (sent_text, section, trigger, doc_id, doc_id_type)
# 140   (sent_text, section, trigger, doc_id, doc_id_type)
# 141   (sent_text, section, trigger, doc_id, doc_id_type)
# 142   (sent_text, section, trigger, doc_id, doc_id_type)
# 143   (sent_text, section, trigger, doc_id, doc_id_type)
# 144   (sent_text, section, trigger, doc_id, doc_id_type)
# 145   (sent_text, section, trigger, doc_id, doc_id_type)
# 146   (sent_text, section, trigger, doc_id, doc_id_type)
# 147   (sent_text, section, trigger, doc_id, doc_id_type)
# 148   (sent_text, section, trigger, doc_id, doc_id_type)
# 149   (sent_text, section, trigger, doc_id, doc_id_type)
# 150   (sent_text, section, trigger, doc_id, doc_id_type)
# 151   (sent_text, section, trigger, doc_id, doc_id_type)
# 152   (sent_text, section, trigger, doc_id, doc_id_type)
# 153   (sent_text, section, trigger, doc_id, doc_id_type)
# 154   (sent_text, section, trigger, doc_id, doc_id_type)
# 155   (sent_text, section, trigger, doc_id, doc_id_type)
# 156   (sent_text, section, trigger, doc_id, doc_id_type)
# 157   (sent_text, section, trigger, doc_id, doc_id_type)
# 158   (sent_text, section, trigger, doc_id, doc_id_type)
# 159   (sent_text, section, trigger, doc_id, doc_id_type)
# 160   (sent_text, section, trigger, doc_id, doc_id_type)
# 161   (sent_text, section, trigger, doc_id, doc_id_type)
# 162   (sent_text, section, trigger, doc_id, doc_id_type)
# 163   (sent_text, section, trigger, doc_id, doc_id_type)
# 164   (sent_text, section, trigger, doc_id, doc_id_type)
# 165   (sent_text, section, trigger, doc_id, doc_id_type)
# 166   (sent_text, section, trigger, doc_id, doc_id_type)
# 167   (sent_text, section, trigger, doc_id, doc_id_type)
# 168   (sent_text, section, trigger, doc_id, doc_id_type)
# 169   (sent_text, section, trigger, doc_id, doc_id_type)
# 170   (sent_text, section, trigger, doc_id, doc_id_type)
# 171   (sent_text, section, trigger, doc_id, doc_id_type)
# 172   (sent_text, section, trigger, doc_id, doc_id_type)
# 173   (sent_text, section, trigger, doc_id, doc_id_type)
# 174   (sent_text, section, trigger, doc_id, doc_id_type)
# 175   (sent_text, section, trigger, doc_id, doc_id_type)
# 176   (sent_text, section, trigger, doc_id, doc_id_type)
# 177   (sent_text, section, trigger, doc_id, doc_id_type)
# 178   (sent_text, section, trigger, doc_id, doc_id_type)
# 179   (sent_text, section, trigger, doc_id, doc_id_type)
# 180   (sent_text, section, trigger, doc_id, doc_id_type)
# 181   (sent_text, section, trigger, doc_id, doc_id_type)
# 182   (sent_text, section, trigger, doc_id, doc_id_type)
# 183   (sent_text, section, trigger, doc_id, doc_id_type)
# 184   (sent_text, section, trigger, doc_id, doc_id_type)
# 185   (sent_text, section, trigger, doc_id, doc_id_type)
# 186   (sent_text, section, trigger, doc_id, doc_id_type)
# 187   (sent_text, section, trigger, doc_id, doc_id_type)
# 188   (sent_text, section, trigger, doc_id, doc_id_type)
# 189   (sent_text, section, trigger, doc_id, doc_id_type)
# 190   (sent_text, section, trigger, doc_id, doc_id_type)
# 191   (sent_text, section, trigger, doc_id, doc_id_type)
# 192   (sent_text, section, trigger, doc_id, doc_id_type)
# 193   (sent_text, section, trigger, doc_id, doc_id_type)
# 194   (sent_text, section, trigger, doc_id, doc_id_type)
# 195   (sent_text, section, trigger, doc_id, doc_id_type)
# 196   (sent_text, section, trigger, doc_id, doc_id_type)
# 197   (sent_text, section, trigger, doc_id, doc_id_type)
# 198   (sent_text, section, trigger, doc_id, doc_id_type)
# 199   (sent_text, section, trigger, doc_id, doc_id_type)
# 200   (sent_text, section, trigger, doc_id, doc_id_type)
# 201   (sent_text, section, trigger, doc_id, doc_id_type)
# 202   (sent_text, section, trigger, doc_id, doc_id_type)
# 203   (sent_text, section, trigger, doc_id, doc_id_type)
# 204   (sent_text, section, trigger, doc_id, doc_id_type)
# 205   (sent_text, section, trigger, doc_id, doc_id_type)
# 206   (sent_text, section, trigger, doc_id, doc_id_type)
# 207   (sent_text, section, trigger, doc_id, doc_id_type)
# 208   (sent_text, section, trigger, doc_id, doc_id_type)
# 209   (sent_text, section, trigger, doc_id, doc_id_type)
# 210   (sent_text, section, trigger, doc_id, doc_id_type)
# 211   (sent_text, section, trigger, doc_id, doc_id_type)
# 212   (sent_text, section, trigger, doc_id, doc_id_type)
# 213   (sent_text, section, trigger, doc_id, doc_id_type)
# 214   (sent_text, section, trigger, doc_id, doc_id_type)
# 215   (sent_text, section, trigger, doc_id, doc_id_type)
# 216   (sent_text, section, trigger, doc_id, doc_id_type)
# 217   (sent_text, section, trigger, doc_id, doc_id_type)
# 218   (sent_text, section, trigger, doc_id, doc_id_type)
# 219   (sent_text, section, trigger, doc_id, doc_id_type)
# 220   (sent_text, section, trigger, doc_id, doc_id_type)
# 221   (sent_text, section, trigger, doc_id, doc_id_type)
# 222   (sent_text, section, trigger, doc_id, doc_id_type)
# 223   (sent_text, section, trigger, doc_id, doc_id_type)
# 224   (sent_text, section, trigger, doc_id, doc_id_type)
# 225   (sent_text, section, trigger, doc_id, doc_id_type)
# 226   (sent_text, section, trigger, doc_id, doc_id_type)
# 227   (sent_text, section, trigger, doc_id, doc_id_type)
# 228   (sent_text, section, trigger, doc_id, doc_id_type)
# 229   (sent_text, section, trigger, doc_id, doc_id_type)
# 230   (sent_text, section, trigger, doc_id, doc_id_type)
# 231   (sent_text, section, trigger, doc_id, doc_id_type)
# 232   (sent_text, section, trigger, doc_id, doc_id_type)
# 233   (sent_text, section, trigger, doc_id, doc_id_type)
# 234   (sent_text, section, trigger, doc_id, doc_id_type)
# 235   (sent_text, section, trigger, doc_id, doc_id_type)
# 236   (sent_text, section, trigger, doc_id, doc_id_type)
# 237   (sent_text, section, trigger, doc_id, doc_id_type)
# 238   (sent_text, section, trigger, doc_id, doc_id_type)
# 239   (sent_text, section, trigger, doc_id, doc_id_type)
# 240   (sent_text, section, trigger, doc_id, doc_id_type)
# 241   (sent_text, section, trigger, doc_id, doc_id_type)
# 242   (sent_text, section, trigger, doc_id, doc_id_type)
# 243   (sent_text, section, trigger, doc_id, doc_id_type)
# 244   (sent_text, section, trigger, doc_id, doc_id_type)
# 245   (sent_text, section, trigger, doc_id, doc_id_type)
# 246   (sent_text, section, trigger, doc_id, doc_id_type)
# 247   (sent_text, section, trigger, doc_id, doc_id_type)
# 248   (sent_text, section, trigger, doc_id, doc_id_type)
# 249   (sent_text, section, trigger, doc_id, doc_id_type)
# 250   (sent_text, section, trigger, doc_id, doc_id_type)
# 251   (sent_text, section, trigger, doc_id, doc_id_type)
# 252   (sent_text, section, trigger, doc_id, doc_id_type)
# 253   (sent_text, section, trigger, doc_id, doc_id_type)
# 254   (sent_text, section, trigger, doc_id, doc_id_type)
# 255   (sent_text, section, trigger, doc_id, doc_id_type)
# 256   (sent_text, section, trigger, doc_id, doc_id_type)
# 257   (sent_text, section, trigger, doc_id, doc_id_type)
# 258   (sent_text, section, trigger, doc_id, doc_id_type)
# 259   (sent_text, section, trigger, doc_id, doc_id_type)
# 260   (sent_text, section, trigger, doc_id, doc_id_type)
# 261   (sent_text, section, trigger, doc_id, doc_id_type)
# 262   (sent_text, section, trigger, doc_id, doc_id_type)
# 263   (sent_text, section, trigger, doc_id, doc_id_type)
# 264   (sent_text, section, trigger, doc_id, doc_id_type)
# 265   (sent_text, section, trigger, doc_id, doc_id_type)
# 266   (sent_text, section, trigger, doc_id, doc_id_type)
# 267   (sent_text, section, trigger, doc_id, doc_id_type)
# 268   (sent_text, section, trigger, doc_id, doc_id_type)
# 269   (sent_text, section, trigger, doc_id, doc_id_type)
# 270   (sent_text, section, trigger, doc_id, doc_id_type)
# 271   (sent_text, section, trigger, doc_id, doc_id_type)
# 272   (sent_text, section, trigger, doc_id, doc_id_type)
# 273   (sent_text, section, trigger, doc_id, doc_id_type)
# 274   (sent_text, section, trigger, doc_id, doc_id_type)
# 275   (sent_text, section, trigger, doc_id, doc_id_type)
# 276   (sent_text, section, trigger, doc_id, doc_id_type)
# 277   (sent_text, section, trigger, doc_id, doc_id_type)
# 278   (sent_text, section, trigger, doc_id, doc_id_type)
# 279   (sent_text, section, trigger, doc_id, doc_id_type)
# 280   (sent_text, section, trigger, doc_id, doc_id_type)
# 281   (sent_text, section, trigger, doc_id, doc_id_type)
# 282   (sent_text, section, trigger, doc_id, doc_id_type)
# 283   (sent_text, section, trigger, doc_id, doc_id_type)
# 284   (sent_text, section, trigger, doc_id, doc_id_type)
# 285   (sent_text, section, trigger, doc_id, doc_id_type)
# 286   (sent_text, section, trigger, doc_id, doc_id_type)
# 287   (sent_text, section, trigger, doc_id, doc_id_type)
# 288   (sent_text, section, trigger, doc_id, doc_id_type)
# 289   (sent_text, section, trigger, doc_id, doc_id_type)
# 290   (sent_text, section, trigger, doc_id, doc_id_type)
# 291   (sent_text, section, trigger, doc_id, doc_id_type)
# 292   (sent_text, section, trigger, doc_id, doc_id_type)
# 293   (sent_text, section, trigger, doc_id, doc_id_type)
# 294   (sent_text, section, trigger, doc_id, doc_id_type)
# 295   (sent_text, section, trigger, doc_id, doc_id_type)
# 296   (sent_text, section, trigger, doc_id, doc_id_type)
# 297   (sent_text, section, trigger, doc_id, doc_id_type)
# 298   (sent_text, section, trigger, doc_id, doc_id_type)
# 299   (sent_text, section, trigger, doc_id, doc_id_type)
# 300   (sent_text, section, trigger, doc_id, doc_id_type)
# 301   (sent_text, section, trigger, doc_id, doc_id_type)
# 302   (sent_text, section, trigger, doc_id, doc_id_type)
# 303   (sent_text, section, trigger, doc_id, doc_id_type)
# 304   (sent_text, section, trigger, doc_id, doc_id_type)
# 305   (sent_text, section, trigger, doc_id, doc_id_type)
# 306   (sent_text, section, trigger, doc_id, doc_id_type)
# 307   (sent_text, section, trigger, doc_id, doc_id_type)
# 308   (sent_text, section, trigger, doc_id, doc_id_type)
# 309   (sent_text, section, trigger, doc_id, doc_id_type)
# 310   (sent_text, section, trigger, doc_id, doc_id_type)
# 311   (sent_text, section, trigger, doc_id, doc_id_type)
# 312   (sent_text, section, trigger, doc_id, doc_id_type)
# 313   (sent_text, section, trigger, doc_id, doc_id_type)
# 314   (sent_text, section, trigger, doc_id, doc_id_type)
# 315   (sent_text, section, trigger, doc_id, doc_id_type)
# 316   (sent_text, section, trigger, doc_id, doc_id_type)
# 317   (sent_text, section, trigger, doc_id, doc_id_type)
# 318   (sent_text, section, trigger, doc_id, doc_id_type)
# 319   (sent_text, section, trigger, doc_id, doc_id_type)
# 320   (sent_text, section, trigger, doc_id, doc_id_type)
# 321   (sent_text, section, trigger, doc_id, doc_id_type)
# 322   (sent_text, section, trigger, doc_id, doc_id_type)
# 323   (sent_text, section, trigger, doc_id, doc_id_type)
# 324   (sent_text, section, trigger, doc_id, doc_id_type)
# 325   (sent_text, section, trigger, doc_id, doc_id_type)
# 326   (sent_text, section, trigger, doc_id, doc_id_type)
# 327   (sent_text, section, trigger, doc_id, doc_id_type)
# 328   (sent_text, section, trigger, doc_id, doc_id_type)
# 329   (sent_text, section, trigger, doc_id, doc_id_type)
# 330   (sent_text, section, trigger, doc_id, doc_id_type)
# 331   (sent_text, section, trigger, doc_id, doc_id_type)
# 332   (sent_text, section, trigger, doc_id, doc_id_type)
# 333   (sent_text, section, trigger, doc_id, doc_id_type)
# 334   (sent_text, section, trigger, doc_id, doc_id_type)
# 335   (sent_text, section, trigger, doc_id, doc_id_type)
# 336   (sent_text, section, trigger, doc_id, doc_id_type)
# 337   (sent_text, section, trigger, doc_id, doc_id_type)
# 338   (sent_text, section, trigger, doc_id, doc_id_type)
# 339   (sent_text, section, trigger, doc_id, doc_id_type)
# 340   (sent_text, section, trigger, doc_id, doc_id_type)
# 341   (sent_text, section, trigger, doc_id, doc_id_type)
# 342   (sent_text, section, trigger, doc_id, doc_id_type)
# 343   (sent_text, section, trigger, doc_id, doc_id_type)
# 344   (sent_text, section, trigger, doc_id, doc_id_type)
# 345   (sent_text, section, trigger, doc_id, doc_id_type)
# 346   (sent_text, section, trigger, doc_id, doc_id_type)
# 347   (sent_text, section, trigger, doc_id, doc_id_type)
# 348   (sent_text, section, trigger, doc_id, doc_id_type)
# 349   (sent_text, section, trigger, doc_id, doc_id_type)
# 350   (sent_text, section, trigger, doc_id, doc_id_type)
# 351   (sent_text, section, trigger, doc_id, doc_id_type)
# 352   (sent_text, section, trigger, doc_id, doc_id_type)
# 353   (sent_text, section, trigger, doc_id, doc_id_type)
# 354   (sent_text, section, trigger, doc_id, doc_id_type)
# 355   (sent_text, section, trigger, doc_id, doc_id_type)
# 356   (sent_text, section, trigger, doc_id, doc_id_type)
# 357   (sent_text, section, trigger, doc_id, doc_id_type)
# 358   (sent_text, section, trigger, doc_id, doc_id_type)
# 359   (sent_text, section, trigger, doc_id, doc_id_type)
# 360   (sent_text, section, trigger, doc_id, doc_id_type)
# 361   (sent_text, section, trigger, doc_id, doc_id_type)
# 362   (sent_text, section, trigger, doc_id, doc_id_type)
# 363   (sent_text, section, trigger, doc_id, doc_id_type)
# 364   (sent_text, section, trigger, doc_id, doc_id_type)
# 365   (sent_text, section, trigger, doc_id, doc_id_type)
# 366   (sent_text, section, trigger, doc_id, doc_id_type)
# 367   (sent_text, section, trigger, doc_id, doc_id_type)
# 368   (sent_text, section, trigger, doc_id, doc_id_type)
# 369   (sent_text, section, trigger, doc_id, doc_id_type)
# 370   (sent_text, section, trigger, doc_id, doc_id_type)
# 371   (sent_text, section, trigger, doc_id, doc_id_type)
# 372   (sent_text, section, trigger, doc_id, doc_id_type)
# 373   (sent_text, section, trigger, doc_id, doc_id_type)
# 374   (sent_text, section, trigger, doc_id, doc_id_type)
# 375   (sent_text, section, trigger, doc_id, doc_id_type)
# 376   (sent_text, section, trigger, doc_id, doc_id_type)
# 377   (sent_text, section, trigger, doc_id, doc_id_type)
# 378   (sent_text, section, trigger, doc_id, doc_id_type)
# 379   (sent_text, section, trigger, doc_id, doc_id_type)
# 380   (sent_text, section, trigger, doc_id, doc_id_type)
# 381   (sent_text, section, trigger, doc_id, doc_id_type)
# 382   (sent_text, section, trigger, doc_id, doc_id_type)
# 383   (sent_text, section, trigger, doc_id, doc_id_type)
# 384   (sent_text, section, trigger, doc_id, doc_id_type)
# 385   (sent_text, section, trigger, doc_id, doc_id_type)
# 386   (sent_text, section, trigger, doc_id, doc_id_type)
# 387   (sent_text, section, trigger, doc_id, doc_id_type)
# 388   (sent_text, section, trigger, doc_id, doc_id_type)
# 389   (sent_text, section, trigger, doc_id, doc_id_type)
# 390   (sent_text, section, trigger, doc_id, doc_id_type)
# 391   (sent_text, section, trigger, doc_id, doc_id_type)
# 392   (sent_text, section, trigger, doc_id, doc_id_type)
# 393   (sent_text, section, trigger, doc_id, doc_id_type)
# 394   (sent_text, section, trigger, doc_id, doc_id_type)
# 395   (sent_text, section, trigger, doc_id, doc_id_type)
# 396   (sent_text, section, trigger, doc_id, doc_id_type)
# 397   (sent_text, section, trigger, doc_id, doc_id_type)
# 398   (sent_text, section, trigger, doc_id, doc_id_type)
# 399   (sent_text, section, trigger, doc_id, doc_id_type)
# 400   (sent_text, section, trigger, doc_id, doc_id_type)
# 401   (sent_text, section, trigger, doc_id, doc_id_type)
# 402   (sent_text, section, trigger, doc_id, doc_id_type)
# 403   (sent_text, section, trigger, doc_id, doc_id_type)
# 404   (sent_text, section, trigger, doc_id, doc_id_type)
# 405   (sent_text, section, trigger, doc_id, doc_id_type)
# 406   (sent_text, section, trigger, doc_id, doc_id_type)
# 407   (sent_text, section, trigger, doc_id, doc_id_type)
# 408   (sent_text, section, trigger, doc_id, doc_id_type)
# 409   (sent_text, section, trigger, doc_id, doc_id_type)
# 410   (sent_text, section, trigger, doc_id, doc_id_type)
# 411   (sent_text, section, trigger, doc_id, doc_id_type)
# 412   (sent_text, section, trigger, doc_id, doc_id_type)
# 413   (sent_text, section, trigger, doc_id, doc_id_type)
# 414   (sent_text, section, trigger, doc_id, doc_id_type)
# 415   (sent_text, section, trigger, doc_id, doc_id_type)
# 416   (sent_text, section, trigger, doc_id, doc_id_type)
# 417   (sent_text, section, trigger, doc_id, doc_id_type)
# 418   (sent_text, section, trigger, doc_id, doc_id_type)
# 419   (sent_text, section, trigger, doc_id, doc_id_type)
# 420   (sent_text, section, trigger, doc_id, doc_id_type)
# 421   (sent_text, section, trigger, doc_id, doc_id_type)
# 422   (sent_text, section, trigger, doc_id, doc_id_type)
# 423   (sent_text, section, trigger, doc_id, doc_id_type)
# 424   (sent_text, section, trigger, doc_id, doc_id_type)
# 425   (sent_text, section, trigger, doc_id, doc_id_type)
# 426   (sent_text, section, trigger, doc_id, doc_id_type)
# 427   (sent_text, section, trigger, doc_id, doc_id_type)
# 428   (sent_text, section, trigger, doc_id, doc_id_type)
# 429   (sent_text, section, trigger, doc_id, doc_id_type)
# 430   (sent_text, section, trigger, doc_id, doc_id_type)
# 431   (sent_text, section, trigger, doc_id, doc_id_type)
# 432   (sent_text, section, trigger, doc_id, doc_id_type)
# 433   (sent_text, section, trigger, doc_id, doc_id_type)
# 434   (sent_text, section, trigger, doc_id, doc_id_type)
# 435   (sent_text, section, trigger, doc_id, doc_id_type)
# 436   (sent_text, section, trigger, doc_id, doc_id_type)
# 437   (sent_text, section, trigger, doc_id, doc_id_type)
# 438   (sent_text, section, trigger, doc_id, doc_id_type)
# 439   (sent_text, section, trigger, doc_id, doc_id_type)
# 440   (sent_text, section, trigger, doc_id, doc_id_type)
# 441   (sent_text, section, trigger, doc_id, doc_id_type)
# 442   (sent_text, section, trigger, doc_id, doc_id_type)
# 443   (sent_text, section, trigger, doc_id, doc_id_type)
# 444   (sent_text, section, trigger, doc_id, doc_id_type)
# 445   (sent_text, section, trigger, doc_id, doc_id_type)
# 446   (sent_text, section, trigger, doc_id, doc_id_type)
# 447   (sent_text, section, trigger, doc_id, doc_id_type)
# 448   (sent_text, section, trigger, doc_id, doc_id_type)
# 449   (sent_text, section, trigger, doc_id, doc_id_type)
# 450   (sent_text, section, trigger, doc_id, doc_id_type)
# 451   (sent_text, section, trigger, doc_id, doc_id_type)
# 452   (sent_text, section, trigger, doc_id, doc_id_type)
# 453   (sent_text, section, trigger, doc_id, doc_id_type)
# 454   (sent_text, section, trigger, doc_id, doc_id_type)
# 455   (sent_text, section, trigger, doc_id, doc_id_type)
# 456   (sent_text, section, trigger, doc_id, doc_id_type)
# 457   (sent_text, section, trigger, doc_id, doc_id_type)
# 458   (sent_text, section, trigger, doc_id, doc_id_type)
# 459   (sent_text, section, trigger, doc_id, doc_id_type)
# 460   (sent_text, section, trigger, doc_id, doc_id_type)
# 461   (sent_text, section, trigger, doc_id, doc_id_type)
# 462   (sent_text, section, trigger, doc_id, doc_id_type)
# 463   (sent_text, section, trigger, doc_id, doc_id_type)
# 464   (sent_text, section, trigger, doc_id, doc_id_type)
# 465   (sent_text, section, trigger, doc_id, doc_id_type)
# 466   (sent_text, section, trigger, doc_id, doc_id_type)
# 467   (sent_text, section, trigger, doc_id, doc_id_type)
# 468   (sent_text, section, trigger, doc_id, doc_id_type)
# 469   (sent_text, section, trigger, doc_id, doc_id_type)
# 470   (sent_text, section, trigger, doc_id, doc_id_type)
# 471   (sent_text, section, trigger, doc_id, doc_id_type)
# 472   (sent_text, section, trigger, doc_id, doc_id_type)
# 473   (sent_text, section, trigger, doc_id, doc_id_type)
# 474   (sent_text, section, trigger, doc_id, doc_id_type)
# 475   (sent_text, section, trigger, doc_id, doc_id_type)
# 476   (sent_text, section, trigger, doc_id, doc_id_type)
# 477   (sent_text, section, trigger, doc_id, doc_id_type)
# 478   (sent_text, section, trigger, doc_id, doc_id_type)
# 479   (sent_text, section, trigger, doc_id, doc_id_type)
# 480   (sent_text, section, trigger, doc_id, doc_id_type)
# 481   (sent_text, section, trigger, doc_id, doc_id_type)
# 482   (sent_text, section, trigger, doc_id, doc_id_type)
# 483   (sent_text, section, trigger, doc_id, doc_id_type)
# 484   (sent_text, section, trigger, doc_id, doc_id_type)
# 485   (sent_text, section, trigger, doc_id, doc_id_type)
# 486   (sent_text, section, trigger, doc_id, doc_id_type)
# 487   (sent_text, section, trigger, doc_id, doc_id_type)
# 488   (sent_text, section, trigger, doc_id, doc_id_type)
# 489   (sent_text, section, trigger, doc_id, doc_id_type)
# 490   (sent_text, section, trigger, doc_id, doc_id_type)
# 491   (sent_text, section, trigger, doc_id, doc_id_type)
# 492   (sent_text, section, trigger, doc_id, doc_id_type)
# 493   (sent_text, section, trigger, doc_id, doc_id_type)
# 494   (sent_text, section, trigger, doc_id, doc_id_type)
# 495   (sent_text, section, trigger, doc_id, doc_id_type)
# 496   (sent_text, section, trigger, doc_id, doc_id_type)
# 497   (sent_text, section, trigger, doc_id, doc_id_type)
# 498   (sent_text, section, trigger, doc_id, doc_id_type)
# 499   (sent_text, section, trigger, doc_id, doc_id_type)
# 500   (sent_text, section, trigger, doc_id, doc_id_type)
# 501   (sent_text, section, trigger, doc_id, doc_id_type)
# 502   (sent_text, section, trigger, doc_id, doc_id_type)
# 503   (sent_text, section, trigger, doc_id, doc_id_type)
# 504   (sent_text, section, trigger, doc_id, doc_id_type)
# 505   (sent_text, section, trigger, doc_id, doc_id_type)
# 506   (sent_text, section, trigger, doc_id, doc_id_type)
# 507   (sent_text, section, trigger, doc_id, doc_id_type)
# 508   (sent_text, section, trigger, doc_id, doc_id_type)
# 509   (sent_text, section, trigger, doc_id, doc_id_type)
# 510   (sent_text, section, trigger, doc_id, doc_id_type)
# 511   (sent_text, section, trigger, doc_id, doc_id_type)
# 512   (sent_text, section, trigger, doc_id, doc_id_type)
# 513   (sent_text, section, trigger, doc_id, doc_id_type)
# 514   (sent_text, section, trigger, doc_id, doc_id_type)
# 515   (sent_text, section, trigger, doc_id, doc_id_type)
# 516   (sent_text, section, trigger, doc_id, doc_id_type)
# 517   (sent_text, section, trigger, doc_id, doc_id_type)
# 518   (sent_text, section, trigger, doc_id, doc_id_type)
# 519   (sent_text, section, trigger, doc_id, doc_id_type)
# 520   (sent_text, section, trigger, doc_id, doc_id_type)
# 521   (sent_text, section, trigger, doc_id, doc_id_type)
# 522   (sent_text, section, trigger, doc_id, doc_id_type)
# 523   (sent_text, section, trigger, doc_id, doc_id_type)
# 524   (sent_text, section, trigger, doc_id, doc_id_type)
# 525   (sent_text, section, trigger, doc_id, doc_id_type)
# 526   (sent_text, section, trigger, doc_id, doc_id_type)
# 527   (sent_text, section, trigger, doc_id, doc_id_type)
# 528   (sent_text, section, trigger, doc_id, doc_id_type)
# 529   (sent_text, section, trigger, doc_id, doc_id_type)
# 530   (sent_text, section, trigger, doc_id, doc_id_type)
# 531   (sent_text, section, trigger, doc_id, doc_id_type)
# 532   (sent_text, section, trigger, doc_id, doc_id_type)
# 533   (sent_text, section, trigger, doc_id, doc_id_type)
# 534   (sent_text, section, trigger, doc_id, doc_id_type)
# 535   (sent_text, section, trigger, doc_id, doc_id_type)
# 536   (sent_text, section, trigger, doc_id, doc_id_type)
# 537   (sent_text, section, trigger, doc_id, doc_id_type)
# 538   (sent_text, section, trigger, doc_id, doc_id_type)
# 539   (sent_text, section, trigger, doc_id, doc_id_type)
# 540   (sent_text, section, trigger, doc_id, doc_id_type)
# 541   (sent_text, section, trigger, doc_id, doc_id_type)
# 542   (sent_text, section, trigger, doc_id, doc_id_type)
# 543   (sent_text, section, trigger, doc_id, doc_id_type)
# 544   (sent_text, section, trigger, doc_id, doc_id_type)
# 545   (sent_text, section, trigger, doc_id, doc_id_type)
# 546   (sent_text, section, trigger, doc_id, doc_id_type)
# 547   (sent_text, section, trigger, doc_id, doc_id_type)
# 548   (sent_text, section, trigger, doc_id, doc_id_type)
# 549   (sent_text, section, trigger, doc_id, doc_id_type)
# 550   (sent_text, section, trigger, doc_id, doc_id_type)
# 551   (sent_text, section, trigger, doc_id, doc_id_type)
# 552   (sent_text, section, trigger, doc_id, doc_id_type)
# 553   (sent_text, section, trigger, doc_id, doc_id_type)
# 554   (sent_text, section, trigger, doc_id, doc_id_type)
# 555   (sent_text, section, trigger, doc_id, doc_id_type)
# 556   (sent_text, section, trigger, doc_id, doc_id_type)
# 557   (sent_text, section, trigger, doc_id, doc_id_type)
# 558   (sent_text, section, trigger, doc_id, doc_id_type)
# 559   (sent_text, section, trigger, doc_id, doc_id_type)
# 560   (sent_text, section, trigger, doc_id, doc_id_type)
# 561   (sent_text, section, trigger, doc_id, doc_id_type)
# 562   (sent_text, section, trigger, doc_id, doc_id_type)
# 563   (sent_text, section, trigger, doc_id, doc_id_type)
# 564   (sent_text, section, trigger, doc_id, doc_id_type)
# 565   (sent_text, section, trigger, doc_id, doc_id_type)
# 566   (sent_text, section, trigger, doc_id, doc_id_type)
# 567   (sent_text, section, trigger, doc_id, doc_id_type)
# 568   (sent_text, section, trigger, doc_id, doc_id_type)
# 569   (sent_text, section, trigger, doc_id, doc_id_type)
# 570   (sent_text, section, trigger, doc_id, doc_id_type)
# 571   (sent_text, section, trigger, doc_id, doc_id_type)
# 572   (sent_text, section, trigger, doc_id, doc_id_type)
# 573   (sent_text, section, trigger, doc_id, doc_id_type)
# 574   (sent_text, section, trigger, doc_id, doc_id_type)
# 575   (sent_text, section, trigger, doc_id, doc_id_type)
# 576   (sent_text, section, trigger, doc_id, doc_id_type)
# 577   (sent_text, section, trigger, doc_id, doc_id_type)
# 578   (sent_text, section, trigger, doc_id, doc_id_type)
# 579   (sent_text, section, trigger, doc_id, doc_id_type)
# 580   (sent_text, section, trigger, doc_id, doc_id_type)
# 581   (sent_text, section, trigger, doc_id, doc_id_type)
# 582   (sent_text, section, trigger, doc_id, doc_id_type)
# 583   (sent_text, section, trigger, doc_id, doc_id_type)
# 584   (sent_text, section, trigger, doc_id, doc_id_type)
# 585   (sent_text, section, trigger, doc_id, doc_id_type)
# 586   (sent_text, section, trigger, doc_id, doc_id_type)
# 587   (sent_text, section, trigger, doc_id, doc_id_type)
# 588   (sent_text, section, trigger, doc_id, doc_id_type)
# 589   (sent_text, section, trigger, doc_id, doc_id_type)
# 590   (sent_text, section, trigger, doc_id, doc_id_type)
# 591   (sent_text, section, trigger, doc_id, doc_id_type)
# 592   (sent_text, section, trigger, doc_id, doc_id_type)
# 593   (sent_text, section, trigger, doc_id, doc_id_type)
# 594   (sent_text, section, trigger, doc_id, doc_id_type)
# 595   (sent_text, section, trigger, doc_id, doc_id_type)
# 596   (sent_text, section, trigger, doc_id, doc_id_type)
# 597   (sent_text, section, trigger, doc_id, doc_id_type)
# 598   (sent_text, section, trigger, doc_id, doc_id_type)
# 599   (sent_text, section, trigger, doc_id, doc_id_type)
# 600   (sent_text, section, trigger, doc_id, doc_id_type)
# 601   (sent_text, section, trigger, doc_id, doc_id_type)
# 602   (sent_text, section, trigger, doc_id, doc_id_type)
# 603   (sent_text, section, trigger, doc_id, doc_id_type)
# 604   (sent_text, section, trigger, doc_id, doc_id_type)
# 605   (sent_text, section, trigger, doc_id, doc_id_type)
# 606   (sent_text, section, trigger, doc_id, doc_id_type)
# 607   (sent_text, section, trigger, doc_id, doc_id_type)
# 608   (sent_text, section, trigger, doc_id, doc_id_type)
# 609   (sent_text, section, trigger, doc_id, doc_id_type)
# 610   (sent_text, section, trigger, doc_id, doc_id_type)
# 611   (sent_text, section, trigger, doc_id, doc_id_type)
# 612   (sent_text, section, trigger, doc_id, doc_id_type)
# 613   (sent_text, section, trigger, doc_id, doc_id_type)
# 614   (sent_text, section, trigger, doc_id, doc_id_type)
# 615   (sent_text, section, trigger, doc_id, doc_id_type)
# 616   (sent_text, section, trigger, doc_id, doc_id_type)
# 617   (sent_text, section, trigger, doc_id, doc_id_type)
# 618   (sent_text, section, trigger, doc_id, doc_id_type)
# 619   (sent_text, section, trigger, doc_id, doc_id_type)
# 620   (sent_text, section, trigger, doc_id, doc_id_type)
# 621   (sent_text, section, trigger, doc_id, doc_id_type)
# 622   (sent_text, section, trigger, doc_id, doc_id_type)
# 623   (sent_text, section, trigger, doc_id, doc_id_type)
# 624   (sent_text, section, trigger, doc_id, doc_id_type)
# 625   (sent_text, section, trigger, doc_id, doc_id_type)
# 626   (sent_text, section, trigger, doc_id, doc_id_type)
# 627   (sent_text, section, trigger, doc_id, doc_id_type)
# 628   (sent_text, section, trigger, doc_id, doc_id_type)
# 629   (sent_text, section, trigger, doc_id, doc_id_type)
# 630   (sent_text, section, trigger, doc_id, doc_id_type)
# 631   (sent_text, section, trigger, doc_id, doc_id_type)
# 632   (sent_text, section, trigger, doc_id, doc_id_type)
# 633   (sent_text, section, trigger, doc_id, doc_id_type)
# 634   (sent_text, section, trigger, doc_id, doc_id_type)
# 635   (sent_text, section, trigger, doc_id, doc_id_type)
# 636   (sent_text, section, trigger, doc_id, doc_id_type)
# 637   (sent_text, section, trigger, doc_id, doc_id_type)
# 638   (sent_text, section, trigger, doc_id, doc_id_type)
# 639   (sent_text, section, trigger, doc_id, doc_id_type)
# 640   (sent_text, section, trigger, doc_id, doc_id_type)
# 641   (sent_text, section, trigger, doc_id, doc_id_type)
# 642   (sent_text, section, trigger, doc_id, doc_id_type)
# 643   (sent_text, section, trigger, doc_id, doc_id_type)
# 644   (sent_text, section, trigger, doc_id, doc_id_type)
# 645   (sent_text, section, trigger, doc_id, doc_id_type)
# 646   (sent_text, section, trigger, doc_id, doc_id_type)
# 647   (sent_text, section, trigger, doc_id, doc_id_type)
# 648   (sent_text, section, trigger, doc_id, doc_id_type)
# 649   (sent_text, section, trigger, doc_id, doc_id_type)
# 650   (sent_text, section, trigger, doc_id, doc_id_type)
# 651   (sent_text, section, trigger, doc_id, doc_id_type)
# 652   (sent_text, section, trigger, doc_id, doc_id_type)
# 653   (sent_text, section, trigger, doc_id, doc_id_type)
# 654   (sent_text, section, trigger, doc_id, doc_id_type)
# 655   (sent_text, section, trigger, doc_id, doc_id_type)
# 656   (sent_text, section, trigger, doc_id, doc_id_type)
# 657   (sent_text, section, trigger, doc_id, doc_id_type)
# 658   (sent_text, section, trigger, doc_id, doc_id_type)
# 659   (sent_text, section, trigger, doc_id, doc_id_type)
# 660   (sent_text, section, trigger, doc_id, doc_id_type)
# 661   (sent_text, section, trigger, doc_id, doc_id_type)
# 662   (sent_text, section, trigger, doc_id, doc_id_type)
# 663   (sent_text, section, trigger, doc_id, doc_id_type)
# 664   (sent_text, section, trigger, doc_id, doc_id_type)
# 665   (sent_text, section, trigger, doc_id, doc_id_type)
# 666   (sent_text, section, trigger, doc_id, doc_id_type)
# 667   (sent_text, section, trigger, doc_id, doc_id_type)
# 668   (sent_text, section, trigger, doc_id, doc_id_type)
# 669   (sent_text, section, trigger, doc_id, doc_id_type)
# 670   (sent_text, section, trigger, doc_id, doc_id_type)
# 671   (sent_text, section, trigger, doc_id, doc_id_type)
# 672   (sent_text, section, trigger, doc_id, doc_id_type)
# 673   (sent_text, section, trigger, doc_id, doc_id_type)
# 674   (sent_text, section, trigger, doc_id, doc_id_type)
# 675   (sent_text, section, trigger, doc_id, doc_id_type)
# 676   (sent_text, section, trigger, doc_id, doc_id_type)
# 677   (sent_text, section, trigger, doc_id, doc_id_type)
# 678   (sent_text, section, trigger, doc_id, doc_id_type)
# 679   (sent_text, section, trigger, doc_id, doc_id_type)
# 680   (sent_text, section, trigger, doc_id, doc_id_type)
# 681   (sent_text, section, trigger, doc_id, doc_id_type)
# 682   (sent_text, section, trigger, doc_id, doc_id_type)
# 683   (sent_text, section, trigger, doc_id, doc_id_type)
# 684   (sent_text, section, trigger, doc_id, doc_id_type)
# 685   (sent_text, section, trigger, doc_id, doc_id_type)
# 686   (sent_text, section, trigger, doc_id, doc_id_type)
# 687   (sent_text, section, trigger, doc_id, doc_id_type)
# 688   (sent_text, section, trigger, doc_id, doc_id_type)
# 689   (sent_text, section, trigger, doc_id, doc_id_type)
# 690   (sent_text, section, trigger, doc_id, doc_id_type)
# 691   (sent_text, section, trigger, doc_id, doc_id_type)
# 692   (sent_text, section, trigger, doc_id, doc_id_type)
# 693   (sent_text, section, trigger, doc_id, doc_id_type)
# 694   (sent_text, section, trigger, doc_id, doc_id_type)
# 695   (sent_text, section, trigger, doc_id, doc_id_type)
# 696   (sent_text, section, trigger, doc_id, doc_id_type)
# 697   (sent_text, section, trigger, doc_id, doc_id_type)
# 698   (sent_text, section, trigger, doc_id, doc_id_type)
# 699   (sent_text, section, trigger, doc_id, doc_id_type)
# 700   (sent_text, section, trigger, doc_id, doc_id_type)
# 701   (sent_text, section, trigger, doc_id, doc_id_type)
# 702   (sent_text, section, trigger, doc_id, doc_id_type)
# 703   (sent_text, section, trigger, doc_id, doc_id_type)
# 704   (sent_text, section, trigger, doc_id, doc_id_type)
# 705   (sent_text, section, trigger, doc_id, doc_id_type)
# 706   (sent_text, section, trigger, doc_id, doc_id_type)
# 707   (sent_text, section, trigger, doc_id, doc_id_type)
# 708   (sent_text, section, trigger, doc_id, doc_id_type)
# 709   (sent_text, section, trigger, doc_id, doc_id_type)
# 710   (sent_text, section, trigger, doc_id, doc_id_type)
# 711   (sent_text, section, trigger, doc_id, doc_id_type)
# 712   (sent_text, section, trigger, doc_id, doc_id_type)
# 713   (sent_text, section, trigger, doc_id, doc_id_type)
# 714   (sent_text, section, trigger, doc_id, doc_id_type)
# 715   (sent_text, section, trigger, doc_id, doc_id_type)
# 716   (sent_text, section, trigger, doc_id, doc_id_type)
# 717   (sent_text, section, trigger, doc_id, doc_id_type)
# 718   (sent_text, section, trigger, doc_id, doc_id_type)
# 719   (sent_text, section, trigger, doc_id, doc_id_type)
# 720   (sent_text, section, trigger, doc_id, doc_id_type)
# 721   (sent_text, section, trigger, doc_id, doc_id_type)
# 722   (sent_text, section, trigger, doc_id, doc_id_type)
# 723   (sent_text, section, trigger, doc_id, doc_id_type)
# 724   (sent_text, section, trigger, doc_id, doc_id_type)
# 725   (sent_text, section, trigger, doc_id, doc_id_type)
# 726   (sent_text, section, trigger, doc_id, doc_id_type)
# 727   (sent_text, section, trigger, doc_id, doc_id_type)
# 728   (sent_text, section, trigger, doc_id, doc_id_type)
# 729   (sent_text, section, trigger, doc_id, doc_id_type)
# 730   (sent_text, section, trigger, doc_id, doc_id_type)
# 731   (sent_text, section, trigger, doc_id, doc_id_type)
# 732   (sent_text, section, trigger, doc_id, doc_id_type)
# 733   (sent_text, section, trigger, doc_id, doc_id_type)
# 734   (sent_text, section, trigger, doc_id, doc_id_type)
# 735   (sent_text, section, trigger, doc_id, doc_id_type)
# 736   (sent_text, section, trigger, doc_id, doc_id_type)
# 737   (sent_text, section, trigger, doc_id, doc_id_type)
# 738   (sent_text, section, trigger, doc_id, doc_id_type)
# 739   (sent_text, section, trigger, doc_id, doc_id_type)
# 740   (sent_text, section, trigger, doc_id, doc_id_type)
# 741   (sent_text, section, trigger, doc_id, doc_id_type)
# 742   (sent_text, section, trigger, doc_id, doc_id_type)
# 743   (sent_text, section, trigger, doc_id, doc_id_type)
# 744   (sent_text, section, trigger, doc_id, doc_id_type)
# 745   (sent_text, section, trigger, doc_id, doc_id_type)
# 746   (sent_text, section, trigger, doc_id, doc_id_type)
# 747   (sent_text, section, trigger, doc_id, doc_id_type)
# 748   (sent_text, section, trigger, doc_id, doc_id_type)
# 749   (sent_text, section, trigger, doc_id, doc_id_type)
# 750   (sent_text, section, trigger, doc_id, doc_id_type)
# 751   (sent_text, section, trigger, doc_id, doc_id_type)
# 752   (sent_text, section, trigger, doc_id, doc_id_type)
# 753   (sent_text, section, trigger, doc_id, doc_id_type)
# 754   (sent_text, section, trigger, doc_id, doc_id_type)
# 755   (sent_text, section, trigger, doc_id, doc_id_type)
# 756   (sent_text, section, trigger, doc_id, doc_id_type)
# 757   (sent_text, section, trigger, doc_id, doc_id_type)
# 758   (sent_text, section, trigger, doc_id, doc_id_type)
# 759   (sent_text, section, trigger, doc_id, doc_id_type)
# 760   (sent_text, section, trigger, doc_id, doc_id_type)
# 761   (sent_text, section, trigger, doc_id, doc_id_type)
# 762   (sent_text, section, trigger, doc_id, doc_id_type)
# 763   (sent_text, section, trigger, doc_id, doc_id_type)
# 764   (sent_text, section, trigger, doc_id, doc_id_type)
# 765   (sent_text, section, trigger, doc_id, doc_id_type)
# 766   (sent_text, section, trigger, doc_id, doc_id_type)
# 767   (sent_text, section, trigger, doc_id, doc_id_type)
# 768   (sent_text, section, trigger, doc_id, doc_id_type)
# 769   (sent_text, section, trigger, doc_id, doc_id_type)
# 770   (sent_text, section, trigger, doc_id, doc_id_type)
# 771   (sent_text, section, trigger, doc_id, doc_id_type)
# 772   (sent_text, section, trigger, doc_id, doc_id_type)
# 773   (sent_text, section, trigger, doc_id, doc_id_type)
# 774   (sent_text, section, trigger, doc_id, doc_id_type)
# 775   (sent_text, section, trigger, doc_id, doc_id_type)
# 776   (sent_text, section, trigger, doc_id, doc_id_type)
# 777   (sent_text, section, trigger, doc_id, doc_id_type)
# 778   (sent_text, section, trigger, doc_id, doc_id_type)
# 779   (sent_text, section, trigger, doc_id, doc_id_type)
# 780   (sent_text, section, trigger, doc_id, doc_id_type)
# 781   (sent_text, section, trigger, doc_id, doc_id_type)
# 782   (sent_text, section, trigger, doc_id, doc_id_type)
# 783   (sent_text, section, trigger, doc_id, doc_id_type)
# 784   (sent_text, section, trigger, doc_id, doc_id_type)
# 785   (sent_text, section, trigger, doc_id, doc_id_type)
# 786   (sent_text, section, trigger, doc_id, doc_id_type)
# 787   (sent_text, section, trigger, doc_id, doc_id_type)
# 788   (sent_text, section, trigger, doc_id, doc_id_type)
# 789   (sent_text, section, trigger, doc_id, doc_id_type)
# 790   (sent_text, section, trigger, doc_id, doc_id_type)
# 791   (sent_text, section, trigger, doc_id, doc_id_type)
# 792   (sent_text, section, trigger, doc_id, doc_id_type)
# 793   (sent_text, section, trigger, doc_id, doc_id_type)
# 794   (sent_text, section, trigger, doc_id, doc_id_type)
# 795   (sent_text, section, trigger, doc_id, doc_id_type)
# 796   (sent_text, section, trigger, doc_id, doc_id_type)
# 797   (sent_text, section, trigger, doc_id, doc_id_type)
# 798   (sent_text, section, trigger, doc_id, doc_id_type)
# 799   (sent_text, section, trigger, doc_id, doc_id_type)
# 800   (sent_text, section, trigger, doc_id, doc_id_type)
# 801   (sent_text, section, trigger, doc_id, doc_id_type)
# 802   (sent_text, section, trigger, doc_id, doc_id_type)
# 803   (sent_text, section, trigger, doc_id, doc_id_type)
# 804   (sent_text, section, trigger, doc_id, doc_id_type)
# 805   (sent_text, section, trigger, doc_id, doc_id_type)
# 806   (sent_text, section, trigger, doc_id, doc_id_type)
# 807   (sent_text, section, trigger, doc_id, doc_id_type)
# 808   (sent_text, section, trigger, doc_id, doc_id_type)
# 809   (sent_text, section, trigger, doc_id, doc_id_type)
# 810   (sent_text, section, trigger, doc_id, doc_id_type)
# 811   (sent_text, section, trigger, doc_id, doc_id_type)
# 812   (sent_text, section, trigger, doc_id, doc_id_type)
# 813   (sent_text, section, trigger, doc_id, doc_id_type)
# 814   (sent_text, section, trigger, doc_id, doc_id_type)
# 815   (sent_text, section, trigger, doc_id, doc_id_type)
# 816   (sent_text, section, trigger, doc_id, doc_id_type)
# 817   (sent_text, section, trigger, doc_id, doc_id_type)
# 818   (sent_text, section, trigger, doc_id, doc_id_type)
# 819   (sent_text, section, trigger, doc_id, doc_id_type)
# 820   (sent_text, section, trigger, doc_id, doc_id_type)
# 821   (sent_text, section, trigger, doc_id, doc_id_type)
# 822   (sent_text, section, trigger, doc_id, doc_id_type)
# 823   (sent_text, section, trigger, doc_id, doc_id_type)
# 824   (sent_text, section, trigger, doc_id, doc_id_type)
# 825   (sent_text, section, trigger, doc_id, doc_id_type)
# 826   (sent_text, section, trigger, doc_id, doc_id_type)
# 827   (sent_text, section, trigger, doc_id, doc_id_type)
# 828   (sent_text, section, trigger, doc_id, doc_id_type)
# 829   (sent_text, section, trigger, doc_id, doc_id_type)
# 830   (sent_text, section, trigger, doc_id, doc_id_type)
# 831   (sent_text, section, trigger, doc_id, doc_id_type)
# 832   (sent_text, section, trigger, doc_id, doc_id_type)
# 833   (sent_text, section, trigger, doc_id, doc_id_type)
# 834   (sent_text, section, trigger, doc_id, doc_id_type)
# 835   (sent_text, section, trigger, doc_id, doc_id_type)
# 836   (sent_text, section, trigger, doc_id, doc_id_type)
# 837   (sent_text, section, trigger, doc_id, doc_id_type)
# 838   (sent_text, section, trigger, doc_id, doc_id_type)
# 839   (sent_text, section, trigger, doc_id, doc_id_type)
# 840   (sent_text, section, trigger, doc_id, doc_id_type)
# ...
# 1630  (sent_text, section, trigger, doc_id, doc_id_type)
# 1631  (sent_text, section, trigger, doc_id, doc_id_type)
# 1632  (sent_text, section, trigger, doc_id, doc_id_type)
# 1633  (sent_text, section, trigger, doc_id, doc_id_type)
# 1634  (sent_text, section, trigger, doc_id, doc_id_type)
# 1635  (sent_text, section, trigger, doc_id, doc_id_type)
# 1636  (sent_text, section, trigger, doc_id, doc_id_type)
# 1637  (sent_text, section, trigger, doc_id, doc_id_type)
# 1638  (sent_text, section, trigger, doc_id, doc_id_type)
# 1639  (sent_text, section, trigger, doc_id, doc_id_type)
# 1640  (sent_text, section, trigger, doc_id, doc_id_type)
# 1641  (sent_text, section, trigger, doc_id, doc_id_type)
# 1642  (sent_text, section, trigger, doc_id, doc_id_type)
# 1643  (sent_text, section, trigger, doc_id, doc_id_type)
# 1644  (sent_text, section, trigger, doc_id, doc_id_type)
# 1645  (sent_text, section, trigger, doc_id, doc_id_type)
# 1646  (sent_text, section, trigger, doc_id, doc_id_type)
# 1647  (sent_text, section, trigger, doc_id, doc_id_type)
# 1648  (sent_text, section, trigger, doc_id, doc_id_type)
# 1649  (sent_text, section, trigger, doc_id, doc_id_type)
# 1650  (sent_text, section, trigger, doc_id, doc_id_type)
# 1651  (sent_text, section, trigger, doc_id, doc_id_type)
# 1652  (sent_text, section, trigger, doc_id, doc_id_type)
# 1653  (sent_text, section, trigger, doc_id, doc_id_type)
# 1654  (sent_text, section, trigger, doc_id, doc_id_type)
# 1655  (sent_text, section, trigger, doc_id, doc_id_type)
# 1656  (sent_text, section, trigger, doc_id, doc_id_type)
# 1657  (sent_text, section, trigger, doc_id, doc_id_type)
# 1658  (sent_text, section, trigger, doc_id, doc_id_type)
# 1659  (sent_text, section, trigger, doc_id, doc_id_type)
# 1660  (sent_text, section, trigger, doc_id, doc_id_type)
# 1661  (sent_text, section, trigger, doc_id, doc_id_type)
# 1662  (sent_text, section, trigger, doc_id, doc_id_type)
# 1663  (sent_text, section, trigger, doc_id, doc_id_type)
# 1664  (sent_text, section, trigger, doc_id, doc_id_type)
# 1665  (sent_text, section, trigger, doc_id, doc_id_type)
# 1666  (sent_text, section, trigger, doc_id, doc_id_type)
# 1667  (sent_text, section, trigger, doc_id, doc_id_type)
# 1668  (sent_text, section, trigger, doc_id, doc_id_type)
# 1669  (sent_text, section, trigger, doc_id, doc_id_type)
# 1670  (sent_text, section, trigger, doc_id, doc_id_type)
# 1671  (sent_text, section, trigger, doc_id, doc_id_type)
# 1672  (sent_text, section, trigger, doc_id, doc_id_type)
# 1673  (sent_text, section, trigger, doc_id, doc_id_type)
# 1674  (sent_text, section, trigger, doc_id, doc_id_type)
# 1675  (sent_text, section, trigger, doc_id, doc_id_type)
# 1676  (sent_text, section, trigger, doc_id, doc_id_type)
# 1677  (sent_text, section, trigger, doc_id, doc_id_type)
# 1678  (sent_text, section, trigger, doc_id, doc_id_type)
# 1679  (sent_text, section, trigger, doc_id, doc_id_type)
# 1680  (sent_text, section, trigger, doc_id, doc_id_type)
# 1681  (sent_text, section, trigger, doc_id, doc_id_type)
# 1682  (sent_text, section, trigger, doc_id, doc_id_type)
# 1683  (sent_text, section, trigger, doc_id, doc_id_type)
# 1684  (sent_text, section, trigger, doc_id, doc_id_type)
# 1685  (sent_text, section, trigger, doc_id, doc_id_type)
# 1686  (sent_text, section, trigger, doc_id, doc_id_type)
# 1687  (sent_text, section, trigger, doc_id, doc_id_type)
# 1688  (sent_text, section, trigger, doc_id, doc_id_type)
# 1689  (sent_text, section, trigger, doc_id, doc_id_type)
# 1690  (sent_text, section, trigger, doc_id, doc_id_type)
# 1691  (sent_text, section, trigger, doc_id, doc_id_type)
# 1692  (sent_text, section, trigger, doc_id, doc_id_type)
# 1693  (sent_text, section, trigger, doc_id, doc_id_type)
# 1694  (sent_text, section, trigger, doc_id, doc_id_type)
# 1695  (sent_text, section, trigger, doc_id, doc_id_type)
# 1696  (sent_text, section, trigger, doc_id, doc_id_type)
# 1697  (sent_text, section, trigger, doc_id, doc_id_type)
# 1698  (sent_text, section, trigger, doc_id, doc_id_type)
# 1699  (sent_text, section, trigger, doc_id, doc_id_type)
# 1700  (sent_text, section, trigger, doc_id, doc_id_type)
# 1701  (sent_text, section, trigger, doc_id, doc_id_type)
# 1702  (sent_text, section, trigger, doc_id, doc_id_type)
# 1703  (sent_text, section, trigger, doc_id, doc_id_type)
# 1704  (sent_text, section, trigger, doc_id, doc_id_type)
# 1705  (sent_text, section, trigger, doc_id, doc_id_type)
# 1706  (sent_text, section, trigger, doc_id, doc_id_type)
# 1707  (sent_text, section, trigger, doc_id, doc_id_type)
# 1708  (sent_text, section, trigger, doc_id, doc_id_type)
# 1709  (sent_text, section, trigger, doc_id, doc_id_type)
# 1710  (sent_text, section, trigger, doc_id, doc_id_type)
# 1711  (sent_text, section, trigger, doc_id, doc_id_type)
# 1712  (sent_text, section, trigger, doc_id, doc_id_type)
# 1713  (sent_text, section, trigger, doc_id, doc_id_type)
# 1714  (sent_text, section, trigger, doc_id, doc_id_type)
# 1715  (sent_text, section, trigger, doc_id, doc_id_type)
# 1716  (sent_text, section, trigger, doc_id, doc_id_type)
# 1717  (sent_text, section, trigger, doc_id, doc_id_type)
# 1718  (sent_text, section, trigger, doc_id, doc_id_type)
# 1719  (sent_text, section, trigger, doc_id, doc_id_type)
# 1720  (sent_text, section, trigger, doc_id, doc_id_type)
# 1721  (sent_text, section, trigger, doc_id, doc_id_type)
# 1722  (sent_text, section, trigger, doc_id, doc_id_type)
# 1723  (sent_text, section, trigger, doc_id, doc_id_type)
# 1724  (sent_text, section, trigger, doc_id, doc_id_type)
# 1725  (sent_text, section, trigger, doc_id, doc_id_type)
# 1726  (sent_text, section, trigger, doc_id, doc_id_type)
# 1727  (sent_text, section, trigger, doc_id, doc_id_type)
# 1728  (sent_text, section, trigger, doc_id, doc_id_type)
# 1729  (sent_text, section, trigger, doc_id, doc_id_type)
# 1730  (sent_text, section, trigger, doc_id, doc_id_type)
# 1731  (sent_text, section, trigger, doc_id, doc_id_type)
# 1732  (sent_text, section, trigger, doc_id, doc_id_type)
# 1733  (sent_text, section, trigger, doc_id, doc_id_type)
# 1734  (sent_text, section, trigger, doc_id, doc_id_type)
# 1735  (sent_text, section, trigger, doc_id, doc_id_type)
# 1736  (sent_text, section, trigger, doc_id, doc_id_type)
# 1737  (sent_text, section, trigger, doc_id, doc_id_type)
# 1738  (sent_text, section, trigger, doc_id, doc_id_type)
# 1739  (sent_text, section, trigger, doc_id, doc_id_type)
# 1740  (sent_text, section, trigger, doc_id, doc_id_type)
# 1741  (sent_text, section, trigger, doc_id, doc_id_type)
# 1742  (sent_text, section, trigger, doc_id, doc_id_type)
# 1743  (sent_text, section, trigger, doc_id, doc_id_type)
# 1744  (sent_text, section, trigger, doc_id, doc_id_type)
# 1745  (sent_text, section, trigger, doc_id, doc_id_type)
# 1746  (sent_text, section, trigger, doc_id, doc_id_type)
# 1747  (sent_text, section, trigger, doc_id, doc_id_type)
# 1748  (sent_text, section, trigger, doc_id, doc_id_type)
# 1749  (sent_text, section, trigger, doc_id, doc_id_type)
# 1750  (sent_text, section, trigger, doc_id, doc_id_type)
# 1751  (sent_text, section, trigger, doc_id, doc_id_type)
# 1752  (sent_text, section, trigger, doc_id, doc_id_type)
# 1753  (sent_text, section, trigger, doc_id, doc_id_type)
# 1754  (sent_text, section, trigger, doc_id, doc_id_type)
# 1755  (sent_text, section, trigger, doc_id, doc_id_type)
# 1756  (sent_text, section, trigger, doc_id, doc_id_type)
# 1757  (sent_text, section, trigger, doc_id, doc_id_type)
# 1758  (sent_text, section, trigger, doc_id, doc_id_type)
# 1759  (sent_text, section, trigger, doc_id, doc_id_type)
# 1760  (sent_text, section, trigger, doc_id, doc_id_type)
# 1761  (sent_text, section, trigger, doc_id, doc_id_type)
# 1762  (sent_text, section, trigger, doc_id, doc_id_type)
# 1763  (sent_text, section, trigger, doc_id, doc_id_type)
# 1764  (sent_text, section, trigger, doc_id, doc_id_type)
# 1765  (sent_text, section, trigger, doc_id, doc_id_type)
# 1766  (sent_text, section, trigger, doc_id, doc_id_type)
# 1767  (sent_text, section, trigger, doc_id, doc_id_type)
# 1768  (sent_text, section, trigger, doc_id, doc_id_type)
# 1769  (sent_text, section, trigger, doc_id, doc_id_type)
# 1770  (sent_text, section, trigger, doc_id, doc_id_type)
# 1771  (sent_text, section, trigger, doc_id, doc_id_type)
# 1772  (sent_text, section, trigger, doc_id, doc_id_type)
# 1773  (sent_text, section, trigger, doc_id, doc_id_type)
# 1774  (sent_text, section, trigger, doc_id, doc_id_type)
# 1775  (sent_text, section, trigger, doc_id, doc_id_type)
# 1776  (sent_text, section, trigger, doc_id, doc_id_type)
# 1777  (sent_text, section, trigger, doc_id, doc_id_type)
# 1778  (sent_text, section, trigger, doc_id, doc_id_type)
# 1779  (sent_text, section, trigger, doc_id, doc_id_type)
# 1780  (sent_text, section, trigger, doc_id, doc_id_type)
# 1781  (sent_text, section, trigger, doc_id, doc_id_type)
# 1782  (sent_text, section, trigger, doc_id, doc_id_type)
# 1783  (sent_text, section, trigger, doc_id, doc_id_type)
# 1784  (sent_text, section, trigger, doc_id, doc_id_type)
# 1785  (sent_text, section, trigger, doc_id, doc_id_type)
# 1786  (sent_text, section, trigger, doc_id, doc_id_type)
# 1787  (sent_text, section, trigger, doc_id, doc_id_type)
# 1788  (sent_text, section, trigger, doc_id, doc_id_type)
# 1789  (sent_text, section, trigger, doc_id, doc_id_type)
# 1790  (sent_text, section, trigger, doc_id, doc_id_type)
# 1791  (sent_text, section, trigger, doc_id, doc_id_type)
# 1792  (sent_text, section, trigger, doc_id, doc_id_type)
# 1793  (sent_text, section, trigger, doc_id, doc_id_type)
# 1794  (sent_text, section, trigger, doc_id, doc_id_type)
# 1795  (sent_text, section, trigger, doc_id, doc_id_type)
# 1796  (sent_text, section, trigger, doc_id, doc_id_type)
# 1797  (sent_text, section, trigger, doc_id, doc_id_type)
# 1798  (sent_text, section, trigger, doc_id, doc_id_type)
# 1799  (sent_text, section, trigger, doc_id, doc_id_type)
# 1800  (sent_text, section, trigger, doc_id, doc_id_type)
# 1801  (sent_text, section, trigger, doc_id, doc_id_type)
# 1802  (sent_text, section, trigger, doc_id, doc_id_type)
# 1803  (sent_text, section, trigger, doc_id, doc_id_type)
# 1804  (sent_text, section, trigger, doc_id, doc_id_type)
# 1805  (sent_text, section, trigger, doc_id, doc_id_type)
# 1806  (sent_text, section, trigger, doc_id, doc_id_type)
# 1807  (sent_text, section, trigger, doc_id, doc_id_type)
# 1808  (sent_text, section, trigger, doc_id, doc_id_type)
# 1809  (sent_text, section, trigger, doc_id, doc_id_type)
# 1810  (sent_text, section, trigger, doc_id, doc_id_type)
# 1811  (sent_text, section, trigger, doc_id, doc_id_type)
# 1812  (sent_text, section, trigger, doc_id, doc_id_type)
# 1813  (sent_text, section, trigger, doc_id, doc_id_type)
# 1814  (sent_text, section, trigger, doc_id, doc_id_type)
# 1815  (sent_text, section, trigger, doc_id, doc_id_type)
# 1816  (sent_text, section, trigger, doc_id, doc_id_type)
# 1817  (sent_text, section, trigger, doc_id, doc_id_type)
# 1818  (sent_text, section, trigger, doc_id, doc_id_type)
# 1819  (sent_text, section, trigger, doc_id, doc_id_type)
# 1820  (sent_text, section, trigger, doc_id, doc_id_type)
# 1821  (sent_text, section, trigger, doc_id, doc_id_type)
# 1822  (sent_text, section, trigger, doc_id, doc_id_type)
# 1823  (sent_text, section, trigger, doc_id, doc_id_type)
# 1824  (sent_text, section, trigger, doc_id, doc_id_type)
# 1825  (sent_text, section, trigger, doc_id, doc_id_type)
# 1826  (sent_text, section, trigger, doc_id, doc_id_type)
# 1827  (sent_text, section, trigger, doc_id, doc_id_type)
# 1828  (sent_text, section, trigger, doc_id, doc_id_type)
# 1829  (sent_text, section, trigger, doc_id, doc_id_type)
# 1830  (sent_text, section, trigger, doc_id, doc_id_type)
# 1831  (sent_text, section, trigger, doc_id, doc_id_type)
# 1832  (sent_text, section, trigger, doc_id, doc_id_type)
# 1833  (sent_text, section, trigger, doc_id, doc_id_type)
# 1834  (sent_text, section, trigger, doc_id, doc_id_type)
# 1835  (sent_text, section, trigger, doc_id, doc_id_type)
# 1836  (sent_text, section, trigger, doc_id, doc_id_type)
# 1837  (sent_text, section, trigger, doc_id, doc_id_type)
# 1838  (sent_text, section, trigger, doc_id, doc_id_type)
# 1839  (sent_text, section, trigger, doc_id, doc_id_type)
# 1840  (sent_text, section, trigger, doc_id, doc_id_type)
# 1841  (sent_text, section, trigger, doc_id, doc_id_type)
# 1842  (sent_text, section, trigger, doc_id, doc_id_type)
# 1843  (sent_text, section, trigger, doc_id, doc_id_type)
# 1844  (sent_text, section, trigger, doc_id, doc_id_type)
# 1845  (sent_text, section, trigger, doc_id, doc_id_type)
# 1846  (sent_text, section, trigger, doc_id, doc_id_type)
# 1847  (sent_text, section, trigger, doc_id, doc_id_type)
# 1848  (sent_text, section, trigger, doc_id, doc_id_type)
# 1849  (sent_text, section, trigger, doc_id, doc_id_type)
# 1850  (sent_text, section, trigger, doc_id, doc_id_type)
# 1851  (sent_text, section, trigger, doc_id, doc_id_type)
# 1852  (sent_text, section, trigger, doc_id, doc_id_type)
# 1853  (sent_text, section, trigger, doc_id, doc_id_type)
# 1854  (sent_text, section, trigger, doc_id, doc_id_type)
# 1855  (sent_text, section, trigger, doc_id, doc_id_type)
# 1856  (sent_text, section, trigger, doc_id, doc_id_type)
# 1857  (sent_text, section, trigger, doc_id, doc_id_type)
# 1858  (sent_text, section, trigger, doc_id, doc_id_type)
# 1859  (sent_text, section, trigger, doc_id, doc_id_type)
# 1860  (sent_text, section, trigger, doc_id, doc_id_type)
# 1861  (sent_text, section, trigger, doc_id, doc_id_type)
# 1862  (sent_text, section, trigger, doc_id, doc_id_type)
# 1863  (sent_text, section, trigger, doc_id, doc_id_type)
# 1864  (sent_text, section, trigger, doc_id, doc_id_type)
# 1865  (sent_text, section, trigger, doc_id, doc_id_type)
# 1866  (sent_text, section, trigger, doc_id, doc_id_type)
# 1867  (sent_text, section, trigger, doc_id, doc_id_type)
# 1868  (sent_text, section, trigger, doc_id, doc_id_type)
# 1869  (sent_text, section, trigger, doc_id, doc_id_type)
# 1870  (sent_text, section, trigger, doc_id, doc_id_type)
# 1871  (sent_text, section, trigger, doc_id, doc_id_type)
# 1872  (sent_text, section, trigger, doc_id, doc_id_type)
# 1873  (sent_text, section, trigger, doc_id, doc_id_type)
# 1874  (sent_text, section, trigger, doc_id, doc_id_type)
# 1875  (sent_text, section, trigger, doc_id, doc_id_type)
# 1876  (sent_text, section, trigger, doc_id, doc_id_type)
# 1877  (sent_text, section, trigger, doc_id, doc_id_type)
# 1878  (sent_text, section, trigger, doc_id, doc_id_type)
# 1879  (sent_text, section, trigger, doc_id, doc_id_type)
# 1880  (sent_text, section, trigger, doc_id, doc_id_type)
# 1881  (sent_text, section, trigger, doc_id, doc_id_type)
# 1882  (sent_text, section, trigger, doc_id, doc_id_type)
# 1883  (sent_text, section, trigger, doc_id, doc_id_type)
# 1884  (sent_text, section, trigger, doc_id, doc_id_type)
# 1885  (sent_text, section, trigger, doc_id, doc_id_type)
# 1886  (sent_text, section, trigger, doc_id, doc_id_type)
# 1887  (sent_text, section, trigger, doc_id, doc_id_type)
# 1888  (sent_text, section, trigger, doc_id, doc_id_type)
# 1889  (sent_text, section, trigger, doc_id, doc_id_type)
# 1890  (sent_text, section, trigger, doc_id, doc_id_type)
# 1891  (sent_text, section, trigger, doc_id, doc_id_type)
# 1892  (sent_text, section, trigger, doc_id, doc_id_type)
# 1893  (sent_text, section, trigger, doc_id, doc_id_type)
# 1894  (sent_text, section, trigger, doc_id, doc_id_type)
# 1895  (sent_text, section, trigger, doc_id, doc_id_type)
# 1896  (sent_text, section, trigger, doc_id, doc_id_type)
# 1897  (sent_text, section, trigger, doc_id, doc_id_type)
# 1898  (sent_text, section, trigger, doc_id, doc_id_type)
# 1899  (sent_text, section, trigger, doc_id, doc_id_type)
# 1900  (sent_text, section, trigger, doc_id, doc_id_type)
# 1901  (sent_text, section, trigger, doc_id, doc_id_type)
# 1902  (sent_text, section, trigger, doc_id, doc_id_type)
# 1903  (sent_text, section, trigger, doc_id, doc_id_type)
# 1904  (sent_text, section, trigger, doc_id, doc_id_type)
# 1905  (sent_text, section, trigger, doc_id, doc_id_type)
# 1906  (sent_text, section, trigger, doc_id, doc_id_type)
# 1907  (sent_text, section, trigger, doc_id, doc_id_type)
# 1908  (sent_text, section, trigger, doc_id, doc_id_type)
# 1909  (sent_text, section, trigger, doc_id, doc_id_type)

# %%
# Correct BookChapter nodes
gds.run_cypher('''
MATCH (n:TextMining) 
WHERE n.doc_id STARTS WITH 'chapter'
set n.doc_id='978-1-4987-6285-4', n.doc_id_type="ISBN", n.isbn = '978-1-4987-6285-4' 
remove n.pmid, n.pmcid 
''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Correct BookChapter edges
gds.run_cypher('''
match()-[r]-() 
WHERE r.doc_id STARTS WITH 'chapter'
set r.doc_id='978-1-4987-6285-4', r.doc_id_type='ISBN'
''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create fulltext search index on textmining nodes
gds.run_cypher('''CREATE FULLTEXT INDEX text_mining_search IF NOT EXISTS FOR (n:TextMining) ON EACH [n.base, n.head, n.np, n.doc_id, n.term, n.type]''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# (optional) exports the whole database incl. indexes as cypher statements to the provided file
gds.run_cypher('''CALL apoc.export.cypher.all('kg_export_after_load_textminig.cypher',{format:'cypher-shell'})''')
