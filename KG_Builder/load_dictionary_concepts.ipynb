# %% [markdown]
# # Load Dictionary Concepts

# %% [markdown]
# This notebook reads in the dictionary concept file ("data/Concepts.obo") in OBO format and convert it into a tab separated values file ("data/Concepts.tsv") for loading into Neo4j database.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

import os 
import configparser
import csv

# %%
# install or import Neo4j GraphDataScience library
try: 
  from graphdatascience import GraphDataScience
  print('Successfully imported GraphDataScience')
except ModuleNotFoundError:
  # !pip3 install graphdatascience
  from graphdatascience import GraphDataScience
  print('installed and imported GraphDataScience')
# Out:
# Successfully imported GraphDataScience

# %% [markdown]
# # Custom Functions

# %%
# function adapted from Neo4j GDS Fraud Demo Notebook (h/t Zach B.) mainly used for connecting to Neo4j database from Python
def read_neo4j_properties(NEO4J_PROPERTIES_FILE: str=None) -> str:
  '''Parses Neo4j database or Aura connection details from provided .ini filepath.
  Requirements:
    configparser

  Args:
    NEO4J_PROPERTIES_FILE: path to a .ini file
  
  Returns:
    HOST: link to Neo4j or Aura host 
    USERNAME: login username
    PASSWORD: login password 

  Note: The .ini file should use the following syntax
    [NEO4J]
    PASSWORD=<password>
    USERNAME=<database name>
    HOST=<host uri>

  If no path is passed, the function will return the defaults:
    HOST = 'neo4j://localhost'
    USERNAME = 'neo4j'
    PASSWORD = 'password'
  '''

  if NEO4J_PROPERTIES_FILE is not None and os.path.exists(NEO4J_PROPERTIES_FILE):
      config = configparser.RawConfigParser()
      config.read(NEO4J_PROPERTIES_FILE)
      HOST = config['NEO4J']['HOST']
      USERNAME = config['NEO4J']['USERNAME']
      PASSWORD = config['NEO4J']['PASSWORD']
      print('Using HOST, USERNAME, PASSWORD from .ini file')
      return HOST, USERNAME, PASSWORD
  else:
      print('Could not find database properties file, using defaults:')
      HOST = 'neo4j://localhost'
      USERNAME = 'neo4j'
      PASSWORD = 'password'
      print(f'HOST: {HOST} \nUSERHAME: {USERNAME} \nPASSWORD: {PASSWORD}')
      return HOST, USERNAME, PASSWORD

# %%
def replace_substring_from_beginning(string, substring, replacement):
  """
  Replaces a substring starting from the beginning of a string.

  Args:
      string: The original string.
      substring: The substring to be replaced.
      replacement: The replacement string.

  Returns:
      The modified string with the substring replaced.
  """

  if not substring:
    return string  # Avoid replacing empty substrings

  if string.startswith(substring):
    return replacement + string[len(substring):]
  else:
    return string

# %%
# function to convert concepts.obo into a TSV file
def obo_to_tsv(concepts_obo_file_path, concepts_tsv_file_path):

    terms = []
    record = []
    alter_names = []
    # Open the file in read mode
    with open(concepts_obo_file_path, "r") as obo_file:
      # Loop through each line

      for line in obo_file:
        if line == "[Term]":
            record = []
            alter_names = []
        elif line.startswith("ConceptName: "):
            record.append(replace_substring_from_beginning(line.strip(), "ConceptName: ", ""))
        elif line.startswith("Id: "):
            record.append(replace_substring_from_beginning(line.strip(), "Id: ", ""))
        elif line.startswith("CanonicalName: "):
            record.append(replace_substring_from_beginning(line.strip(), "CanonicalName: ", ""))
        elif line.startswith("Type: "):
            record.append(replace_substring_from_beginning(line.strip(), "Type: ", ""))
        elif line.startswith("TypeId: "):
            record.append(replace_substring_from_beginning(line.strip(), "TypeId: ", ""))
        elif line.startswith("AlternativeNames: "):
            alter_names.append(replace_substring_from_beginning(line, "AlternativeNames: ", "").strip())
        elif len(record) > 0 and line == "\n":
            if len(alter_names):
                record.append("; ".join(alter_names))
            terms.append("\t".join(record)+"\n")
            record = []
            alter_names = []
        

    obo_file.close()
    # open TSV file for writing
    with open(concepts_tsv_file_path, "w") as tsv_file:
        # write to file
        term_header = f"concept_name\tid\tcanonical_name\ttype\ttype_id\talter_names\n"
        tsv_file.write(term_header)
        for term in terms:
            tsv_file.write(term)
    tsv_file.close()

# %%
# Convert dictionary concepts in OBO format into TSV format.
obo_to_tsv("data/Concepts.obo", "data/Concepts.tsv")

# %% [markdown]
# # Connect to Neo4j DB
# It is recommended to store authentication credentials in a separate file and read them in to the notebook as variables. This code assumes the files are stored in a local auth directory.

# %%
# get authentication credentials from local auth file
NEO4J_PROPERTIES_FILE = 'auth/immerse_kg_auth.ini'
HOST, USERNAME, PASSWORD = read_neo4j_properties(NEO4J_PROPERTIES_FILE=NEO4J_PROPERTIES_FILE)
# Out:
# Using HOST, USERNAME, PASSWORD from .ini file

# %%
# connect to neo4j instance 
gds = GraphDataScience(HOST, auth=(USERNAME, PASSWORD), aura_ds=False)

# %%
# confirm connection with GDS version 
gds.version()
# Out:
# '2.5.0'

# %% [markdown]
# # Cleanup Dictionary Concepts

# %%
# if the step of loading dictionary concepts failed or want to reload dictionary concepts, clear out the dictonary concepts from the database
gds.run_cypher('''
                MATCH (n:DictionaryConcept)
                DETACH DELETE n
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# read concepts.tsv file
dictionary_concept_nodes = pd.read_csv('data/Concepts.tsv', sep='\t', header=0).fillna('NA') 
dictionary_concept_nodes.head().to_dict(orient='records')
# Out:
# [{'concept_name': '(fut8) gene knockout cho-s_COID438040',
#   'id': 'COID438040',
#   'canonical_name': '(fut8) gene knockout cho-s',
#   'type': 'chinese hamster ovary (CHO)',
#   'type_id': 'C58',
#   'alter_names': 'fut8 gene knockout cho-s'},
#  {'concept_name': '1-ag4-1_COID898401',
#   'id': 'COID898401',
#   'canonical_name': '1-ag4-1',
#   'type': 'hybridoma',
#   'type_id': 'C57',
#   'alter_names': 'NA'},
#  {'concept_name': '2-f-peracetyl fucose_COID847827',
#   'id': 'COID847827',
#   'canonical_name': '2-f-peracetyl fucose',
#   'type': 'sugar (subset of carbon source)',
#   'type_id': 'C27',
#   'alter_names': 'NA'},
#  {'concept_name': 'FA2G1_COID847899',
#   'id': 'COID847899',
#   'canonical_name': 'FA2G1',
#   'type': 'sugar (subset of carbon source)',
#   'type_id': 'C27',
#   'alter_names': 'NA'},
#  {'concept_name': 'FUC8_COID847828',
#   'id': 'COID847828',
#   'canonical_name': 'FUC8',
#   'type': 'sugar (subset of carbon source)',
#   'type_id': 'C27',
#   'alter_names': 'NA'}]

# %%
# Create contraint on Concept nodes
gds.run_cypher('''CREATE CONSTRAINT dictionary_concept IF NOT EXISTS FOR (c:DictionaryConcept) REQUIRE c.id IS UNIQUE''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Check the constraint created in the step above.
gds.run_cypher('''SHOW CONSTRAINTS''')
# Out:
#    id                 name        type entityType         labelsOrTypes  \
# 0   5   dictionary_concept  UNIQUENESS       NODE   [DictionaryConcept]
# 1   2  ontological_concept  UNIQUENESS       NODE  [OntologicalConcept]
#
#   properties           ownedIndex
# 0       [id]   dictionary_concept
# 1       [id]  ontological_concept

# %% [markdown]
# # Load Dictionary Concept

# %%
# Load DictionaryConcept nodes into Neo4j database
gds.run_cypher('''
               UNWIND $node_list AS node
               CALL apoc.merge.node (["DictionaryConcept"], {id: node.id, concept_name: node.concept_name, canonical_name: node.canonical_name, type: node.type, type_id: node.type_id, alter_names: node.alter_names })
               YIELD node as n 
               RETURN n
              ''', {'node_list': dictionary_concept_nodes.to_dict('records')})
# Out:
#                                                                   n
# 0    (concept_name, alter_names, canonical_name, type_id, id, type)
# 1    (concept_name, alter_names, canonical_name, type_id, id, type)
# 2    (concept_name, alter_names, canonical_name, type_id, id, type)
# 3    (concept_name, alter_names, canonical_name, type_id, id, type)
# 4    (concept_name, alter_names, canonical_name, type_id, id, type)
# 5    (concept_name, alter_names, canonical_name, type_id, id, type)
# 6    (concept_name, alter_names, canonical_name, type_id, id, type)
# 7    (concept_name, alter_names, canonical_name, type_id, id, type)
# 8    (concept_name, alter_names, canonical_name, type_id, id, type)
# 9    (concept_name, alter_names, canonical_name, type_id, id, type)
# 10   (concept_name, alter_names, canonical_name, type_id, id, type)
# 11   (concept_name, alter_names, canonical_name, type_id, id, type)
# 12   (concept_name, alter_names, canonical_name, type_id, id, type)
# 13   (concept_name, alter_names, canonical_name, type_id, id, type)
# 14   (concept_name, alter_names, canonical_name, type_id, id, type)
# 15   (concept_name, alter_names, canonical_name, type_id, id, type)
# 16   (concept_name, alter_names, canonical_name, type_id, id, type)
# 17   (concept_name, alter_names, canonical_name, type_id, id, type)
# 18   (concept_name, alter_names, canonical_name, type_id, id, type)
# 19   (concept_name, alter_names, canonical_name, type_id, id, type)
# 20   (concept_name, alter_names, canonical_name, type_id, id, type)
# 21   (concept_name, alter_names, canonical_name, type_id, id, type)
# 22   (concept_name, alter_names, canonical_name, type_id, id, type)
# 23   (concept_name, alter_names, canonical_name, type_id, id, type)
# 24   (concept_name, alter_names, canonical_name, type_id, id, type)
# 25   (concept_name, alter_names, canonical_name, type_id, id, type)
# 26   (concept_name, alter_names, canonical_name, type_id, id, type)
# 27   (concept_name, alter_names, canonical_name, type_id, id, type)
# 28   (concept_name, alter_names, canonical_name, type_id, id, type)
# 29   (concept_name, alter_names, canonical_name, type_id, id, type)
# 30   (concept_name, alter_names, canonical_name, type_id, id, type)
# 31   (concept_name, alter_names, canonical_name, type_id, id, type)
# 32   (concept_name, alter_names, canonical_name, type_id, id, type)
# 33   (concept_name, alter_names, canonical_name, type_id, id, type)
# 34   (concept_name, alter_names, canonical_name, type_id, id, type)
# 35   (concept_name, alter_names, canonical_name, type_id, id, type)
# 36   (concept_name, alter_names, canonical_name, type_id, id, type)
# 37   (concept_name, alter_names, canonical_name, type_id, id, type)
# 38   (concept_name, alter_names, canonical_name, type_id, id, type)
# 39   (concept_name, alter_names, canonical_name, type_id, id, type)
# 40   (concept_name, alter_names, canonical_name, type_id, id, type)
# 41   (concept_name, alter_names, canonical_name, type_id, id, type)
# 42   (concept_name, alter_names, canonical_name, type_id, id, type)
# 43   (concept_name, alter_names, canonical_name, type_id, id, type)
# 44   (concept_name, alter_names, canonical_name, type_id, id, type)
# 45   (concept_name, alter_names, canonical_name, type_id, id, type)
# 46   (concept_name, alter_names, canonical_name, type_id, id, type)
# 47   (concept_name, alter_names, canonical_name, type_id, id, type)
# 48   (concept_name, alter_names, canonical_name, type_id, id, type)
# 49   (concept_name, alter_names, canonical_name, type_id, id, type)
# 50   (concept_name, alter_names, canonical_name, type_id, id, type)
# 51   (concept_name, alter_names, canonical_name, type_id, id, type)
# 52   (concept_name, alter_names, canonical_name, type_id, id, type)
# 53   (concept_name, alter_names, canonical_name, type_id, id, type)
# 54   (concept_name, alter_names, canonical_name, type_id, id, type)
# 55   (concept_name, alter_names, canonical_name, type_id, id, type)
# 56   (concept_name, alter_names, canonical_name, type_id, id, type)
# 57   (concept_name, alter_names, canonical_name, type_id, id, type)
# 58   (concept_name, alter_names, canonical_name, type_id, id, type)
# 59   (concept_name, alter_names, canonical_name, type_id, id, type)
# 60   (concept_name, alter_names, canonical_name, type_id, id, type)
# 61   (concept_name, alter_names, canonical_name, type_id, id, type)
# 62   (concept_name, alter_names, canonical_name, type_id, id, type)
# 63   (concept_name, alter_names, canonical_name, type_id, id, type)
# 64   (concept_name, alter_names, canonical_name, type_id, id, type)
# 65   (concept_name, alter_names, canonical_name, type_id, id, type)
# 66   (concept_name, alter_names, canonical_name, type_id, id, type)
# 67   (concept_name, alter_names, canonical_name, type_id, id, type)
# 68   (concept_name, alter_names, canonical_name, type_id, id, type)
# 69   (concept_name, alter_names, canonical_name, type_id, id, type)
# 70   (concept_name, alter_names, canonical_name, type_id, id, type)
# 71   (concept_name, alter_names, canonical_name, type_id, id, type)
# 72   (concept_name, alter_names, canonical_name, type_id, id, type)
# 73   (concept_name, alter_names, canonical_name, type_id, id, type)
# 74   (concept_name, alter_names, canonical_name, type_id, id, type)
# 75   (concept_name, alter_names, canonical_name, type_id, id, type)
# 76   (concept_name, alter_names, canonical_name, type_id, id, type)
# 77   (concept_name, alter_names, canonical_name, type_id, id, type)
# 78   (concept_name, alter_names, canonical_name, type_id, id, type)
# 79   (concept_name, alter_names, canonical_name, type_id, id, type)
# 80   (concept_name, alter_names, canonical_name, type_id, id, type)
# 81   (concept_name, alter_names, canonical_name, type_id, id, type)
# 82   (concept_name, alter_names, canonical_name, type_id, id, type)
# 83   (concept_name, alter_names, canonical_name, type_id, id, type)
# 84   (concept_name, alter_names, canonical_name, type_id, id, type)
# 85   (concept_name, alter_names, canonical_name, type_id, id, type)
# 86   (concept_name, alter_names, canonical_name, type_id, id, type)
# 87   (concept_name, alter_names, canonical_name, type_id, id, type)
# 88   (concept_name, alter_names, canonical_name, type_id, id, type)
# 89   (concept_name, alter_names, canonical_name, type_id, id, type)
# 90   (concept_name, alter_names, canonical_name, type_id, id, type)
# 91   (concept_name, alter_names, canonical_name, type_id, id, type)
# 92   (concept_name, alter_names, canonical_name, type_id, id, type)
# 93   (concept_name, alter_names, canonical_name, type_id, id, type)
# 94   (concept_name, alter_names, canonical_name, type_id, id, type)
# 95   (concept_name, alter_names, canonical_name, type_id, id, type)
# 96   (concept_name, alter_names, canonical_name, type_id, id, type)
# 97   (concept_name, alter_names, canonical_name, type_id, id, type)
# 98   (concept_name, alter_names, canonical_name, type_id, id, type)
# 99   (concept_name, alter_names, canonical_name, type_id, id, type)
# 100  (concept_name, alter_names, canonical_name, type_id, id, type)
# 101  (concept_name, alter_names, canonical_name, type_id, id, type)
# 102  (concept_name, alter_names, canonical_name, type_id, id, type)
# 103  (concept_name, alter_names, canonical_name, type_id, id, type)
# 104  (concept_name, alter_names, canonical_name, type_id, id, type)
# 105  (concept_name, alter_names, canonical_name, type_id, id, type)
# 106  (concept_name, alter_names, canonical_name, type_id, id, type)
# 107  (concept_name, alter_names, canonical_name, type_id, id, type)
# 108  (concept_name, alter_names, canonical_name, type_id, id, type)
# 109  (concept_name, alter_names, canonical_name, type_id, id, type)
# 110  (concept_name, alter_names, canonical_name, type_id, id, type)
# 111  (concept_name, alter_names, canonical_name, type_id, id, type)
# 112  (concept_name, alter_names, canonical_name, type_id, id, type)
# 113  (concept_name, alter_names, canonical_name, type_id, id, type)
# 114  (concept_name, alter_names, canonical_name, type_id, id, type)
# 115  (concept_name, alter_names, canonical_name, type_id, id, type)
# 116  (concept_name, alter_names, canonical_name, type_id, id, type)
# 117  (concept_name, alter_names, canonical_name, type_id, id, type)
# 118  (concept_name, alter_names, canonical_name, type_id, id, type)
# 119  (concept_name, alter_names, canonical_name, type_id, id, type)
# 120  (concept_name, alter_names, canonical_name, type_id, id, type)
# 121  (concept_name, alter_names, canonical_name, type_id, id, type)
# 122  (concept_name, alter_names, canonical_name, type_id, id, type)
# 123  (concept_name, alter_names, canonical_name, type_id, id, type)
# 124  (concept_name, alter_names, canonical_name, type_id, id, type)
# 125  (concept_name, alter_names, canonical_name, type_id, id, type)
# 126  (concept_name, alter_names, canonical_name, type_id, id, type)
# 127  (concept_name, alter_names, canonical_name, type_id, id, type)
# 128  (concept_name, alter_names, canonical_name, type_id, id, type)
# 129  (concept_name, alter_names, canonical_name, type_id, id, type)
# 130  (concept_name, alter_names, canonical_name, type_id, id, type)
# 131  (concept_name, alter_names, canonical_name, type_id, id, type)
# 132  (concept_name, alter_names, canonical_name, type_id, id, type)
# 133  (concept_name, alter_names, canonical_name, type_id, id, type)
# 134  (concept_name, alter_names, canonical_name, type_id, id, type)
# 135  (concept_name, alter_names, canonical_name, type_id, id, type)
# 136  (concept_name, alter_names, canonical_name, type_id, id, type)
# 137  (concept_name, alter_names, canonical_name, type_id, id, type)
# 138  (concept_name, alter_names, canonical_name, type_id, id, type)
# 139  (concept_name, alter_names, canonical_name, type_id, id, type)
# 140  (concept_name, alter_names, canonical_name, type_id, id, type)
# 141  (concept_name, alter_names, canonical_name, type_id, id, type)
# 142  (concept_name, alter_names, canonical_name, type_id, id, type)
# 143  (concept_name, alter_names, canonical_name, type_id, id, type)
# 144  (concept_name, alter_names, canonical_name, type_id, id, type)
# 145  (concept_name, alter_names, canonical_name, type_id, id, type)
# 146  (concept_name, alter_names, canonical_name, type_id, id, type)
# 147  (concept_name, alter_names, canonical_name, type_id, id, type)
# 148  (concept_name, alter_names, canonical_name, type_id, id, type)
# 149  (concept_name, alter_names, canonical_name, type_id, id, type)
# 150  (concept_name, alter_names, canonical_name, type_id, id, type)
# 151  (concept_name, alter_names, canonical_name, type_id, id, type)
# 152  (concept_name, alter_names, canonical_name, type_id, id, type)
# 153  (concept_name, alter_names, canonical_name, type_id, id, type)
# 154  (concept_name, alter_names, canonical_name, type_id, id, type)
# 155  (concept_name, alter_names, canonical_name, type_id, id, type)
# 156  (concept_name, alter_names, canonical_name, type_id, id, type)
# 157  (concept_name, alter_names, canonical_name, type_id, id, type)
# 158  (concept_name, alter_names, canonical_name, type_id, id, type)
# 159  (concept_name, alter_names, canonical_name, type_id, id, type)
# 160  (concept_name, alter_names, canonical_name, type_id, id, type)
# 161  (concept_name, alter_names, canonical_name, type_id, id, type)
# 162  (concept_name, alter_names, canonical_name, type_id, id, type)
# 163  (concept_name, alter_names, canonical_name, type_id, id, type)
# 164  (concept_name, alter_names, canonical_name, type_id, id, type)
# 165  (concept_name, alter_names, canonical_name, type_id, id, type)
# 166  (concept_name, alter_names, canonical_name, type_id, id, type)
# 167  (concept_name, alter_names, canonical_name, type_id, id, type)
# 168  (concept_name, alter_names, canonical_name, type_id, id, type)
# 169  (concept_name, alter_names, canonical_name, type_id, id, type)
# 170  (concept_name, alter_names, canonical_name, type_id, id, type)
# 171  (concept_name, alter_names, canonical_name, type_id, id, type)
# 172  (concept_name, alter_names, canonical_name, type_id, id, type)
# 173  (concept_name, alter_names, canonical_name, type_id, id, type)
# 174  (concept_name, alter_names, canonical_name, type_id, id, type)
# 175  (concept_name, alter_names, canonical_name, type_id, id, type)
# 176  (concept_name, alter_names, canonical_name, type_id, id, type)
# 177  (concept_name, alter_names, canonical_name, type_id, id, type)
# 178  (concept_name, alter_names, canonical_name, type_id, id, type)
# 179  (concept_name, alter_names, canonical_name, type_id, id, type)
# 180  (concept_name, alter_names, canonical_name, type_id, id, type)
# 181  (concept_name, alter_names, canonical_name, type_id, id, type)
# 182  (concept_name, alter_names, canonical_name, type_id, id, type)
# 183  (concept_name, alter_names, canonical_name, type_id, id, type)
# 184  (concept_name, alter_names, canonical_name, type_id, id, type)
# 185  (concept_name, alter_names, canonical_name, type_id, id, type)
# 186  (concept_name, alter_names, canonical_name, type_id, id, type)
# 187  (concept_name, alter_names, canonical_name, type_id, id, type)
# 188  (concept_name, alter_names, canonical_name, type_id, id, type)
# 189  (concept_name, alter_names, canonical_name, type_id, id, type)
# 190  (concept_name, alter_names, canonical_name, type_id, id, type)
# 191  (concept_name, alter_names, canonical_name, type_id, id, type)
# 192  (concept_name, alter_names, canonical_name, type_id, id, type)
# 193  (concept_name, alter_names, canonical_name, type_id, id, type)
# 194  (concept_name, alter_names, canonical_name, type_id, id, type)
# 195  (concept_name, alter_names, canonical_name, type_id, id, type)
# 196  (concept_name, alter_names, canonical_name, type_id, id, type)
# 197  (concept_name, alter_names, canonical_name, type_id, id, type)
# 198  (concept_name, alter_names, canonical_name, type_id, id, type)
# 199  (concept_name, alter_names, canonical_name, type_id, id, type)
# 200  (concept_name, alter_names, canonical_name, type_id, id, type)
# 201  (concept_name, alter_names, canonical_name, type_id, id, type)
# 202  (concept_name, alter_names, canonical_name, type_id, id, type)
# 203  (concept_name, alter_names, canonical_name, type_id, id, type)
# 204  (concept_name, alter_names, canonical_name, type_id, id, type)
# 205  (concept_name, alter_names, canonical_name, type_id, id, type)
# 206  (concept_name, alter_names, canonical_name, type_id, id, type)
# 207  (concept_name, alter_names, canonical_name, type_id, id, type)
# 208  (concept_name, alter_names, canonical_name, type_id, id, type)
# 209  (concept_name, alter_names, canonical_name, type_id, id, type)
# 210  (concept_name, alter_names, canonical_name, type_id, id, type)
# 211  (concept_name, alter_names, canonical_name, type_id, id, type)
# 212  (concept_name, alter_names, canonical_name, type_id, id, type)
# 213  (concept_name, alter_names, canonical_name, type_id, id, type)
# 214  (concept_name, alter_names, canonical_name, type_id, id, type)
# 215  (concept_name, alter_names, canonical_name, type_id, id, type)
# 216  (concept_name, alter_names, canonical_name, type_id, id, type)
# 217  (concept_name, alter_names, canonical_name, type_id, id, type)
# 218  (concept_name, alter_names, canonical_name, type_id, id, type)
# 219  (concept_name, alter_names, canonical_name, type_id, id, type)
# 220  (concept_name, alter_names, canonical_name, type_id, id, type)
# 221  (concept_name, alter_names, canonical_name, type_id, id, type)
# 222  (concept_name, alter_names, canonical_name, type_id, id, type)
# 223  (concept_name, alter_names, canonical_name, type_id, id, type)
# 224  (concept_name, alter_names, canonical_name, type_id, id, type)
# 225  (concept_name, alter_names, canonical_name, type_id, id, type)
# 226  (concept_name, alter_names, canonical_name, type_id, id, type)
# 227  (concept_name, alter_names, canonical_name, type_id, id, type)
# 228  (concept_name, alter_names, canonical_name, type_id, id, type)
# 229  (concept_name, alter_names, canonical_name, type_id, id, type)
# 230  (concept_name, alter_names, canonical_name, type_id, id, type)
# 231  (concept_name, alter_names, canonical_name, type_id, id, type)
# 232  (concept_name, alter_names, canonical_name, type_id, id, type)
# 233  (concept_name, alter_names, canonical_name, type_id, id, type)
# 234  (concept_name, alter_names, canonical_name, type_id, id, type)
# 235  (concept_name, alter_names, canonical_name, type_id, id, type)
# 236  (concept_name, alter_names, canonical_name, type_id, id, type)
# 237  (concept_name, alter_names, canonical_name, type_id, id, type)
# 238  (concept_name, alter_names, canonical_name, type_id, id, type)
# 239  (concept_name, alter_names, canonical_name, type_id, id, type)
# 240  (concept_name, alter_names, canonical_name, type_id, id, type)
# 241  (concept_name, alter_names, canonical_name, type_id, id, type)
# 242  (concept_name, alter_names, canonical_name, type_id, id, type)
# 243  (concept_name, alter_names, canonical_name, type_id, id, type)
# 244  (concept_name, alter_names, canonical_name, type_id, id, type)
# 245  (concept_name, alter_names, canonical_name, type_id, id, type)
# 246  (concept_name, alter_names, canonical_name, type_id, id, type)
# 247  (concept_name, alter_names, canonical_name, type_id, id, type)
# 248  (concept_name, alter_names, canonical_name, type_id, id, type)
# 249  (concept_name, alter_names, canonical_name, type_id, id, type)
# 250  (concept_name, alter_names, canonical_name, type_id, id, type)
# 251  (concept_name, alter_names, canonical_name, type_id, id, type)
# 252  (concept_name, alter_names, canonical_name, type_id, id, type)
# 253  (concept_name, alter_names, canonical_name, type_id, id, type)
# 254  (concept_name, alter_names, canonical_name, type_id, id, type)
# 255  (concept_name, alter_names, canonical_name, type_id, id, type)
# 256  (concept_name, alter_names, canonical_name, type_id, id, type)
# 257  (concept_name, alter_names, canonical_name, type_id, id, type)
# 258  (concept_name, alter_names, canonical_name, type_id, id, type)
# 259  (concept_name, alter_names, canonical_name, type_id, id, type)
# 260  (concept_name, alter_names, canonical_name, type_id, id, type)
# 261  (concept_name, alter_names, canonical_name, type_id, id, type)
# 262  (concept_name, alter_names, canonical_name, type_id, id, type)
# 263  (concept_name, alter_names, canonical_name, type_id, id, type)
# 264  (concept_name, alter_names, canonical_name, type_id, id, type)
# 265  (concept_name, alter_names, canonical_name, type_id, id, type)
# 266  (concept_name, alter_names, canonical_name, type_id, id, type)
# 267  (concept_name, alter_names, canonical_name, type_id, id, type)
# 268  (concept_name, alter_names, canonical_name, type_id, id, type)
# 269  (concept_name, alter_names, canonical_name, type_id, id, type)
# 270  (concept_name, alter_names, canonical_name, type_id, id, type)
# 271  (concept_name, alter_names, canonical_name, type_id, id, type)
# 272  (concept_name, alter_names, canonical_name, type_id, id, type)
# 273  (concept_name, alter_names, canonical_name, type_id, id, type)
# 274  (concept_name, alter_names, canonical_name, type_id, id, type)
# 275  (concept_name, alter_names, canonical_name, type_id, id, type)
# 276  (concept_name, alter_names, canonical_name, type_id, id, type)
# 277  (concept_name, alter_names, canonical_name, type_id, id, type)
# 278  (concept_name, alter_names, canonical_name, type_id, id, type)
# 279  (concept_name, alter_names, canonical_name, type_id, id, type)
# 280  (concept_name, alter_names, canonical_name, type_id, id, type)
# 281  (concept_name, alter_names, canonical_name, type_id, id, type)
# 282  (concept_name, alter_names, canonical_name, type_id, id, type)
# 283  (concept_name, alter_names, canonical_name, type_id, id, type)
# 284  (concept_name, alter_names, canonical_name, type_id, id, type)
# 285  (concept_name, alter_names, canonical_name, type_id, id, type)
# 286  (concept_name, alter_names, canonical_name, type_id, id, type)
# 287  (concept_name, alter_names, canonical_name, type_id, id, type)
# 288  (concept_name, alter_names, canonical_name, type_id, id, type)
# 289  (concept_name, alter_names, canonical_name, type_id, id, type)
# 290  (concept_name, alter_names, canonical_name, type_id, id, type)
# 291  (concept_name, alter_names, canonical_name, type_id, id, type)
# 292  (concept_name, alter_names, canonical_name, type_id, id, type)
# 293  (concept_name, alter_names, canonical_name, type_id, id, type)
# 294  (concept_name, alter_names, canonical_name, type_id, id, type)
# 295  (concept_name, alter_names, canonical_name, type_id, id, type)
# 296  (concept_name, alter_names, canonical_name, type_id, id, type)
# 297  (concept_name, alter_names, canonical_name, type_id, id, type)
# 298  (concept_name, alter_names, canonical_name, type_id, id, type)
# 299  (concept_name, alter_names, canonical_name, type_id, id, type)
# 300  (concept_name, alter_names, canonical_name, type_id, id, type)
# 301  (concept_name, alter_names, canonical_name, type_id, id, type)
# 302  (concept_name, alter_names, canonical_name, type_id, id, type)
# 303  (concept_name, alter_names, canonical_name, type_id, id, type)
# 304  (concept_name, alter_names, canonical_name, type_id, id, type)
# 305  (concept_name, alter_names, canonical_name, type_id, id, type)
# 306  (concept_name, alter_names, canonical_name, type_id, id, type)
# 307  (concept_name, alter_names, canonical_name, type_id, id, type)
# 308  (concept_name, alter_names, canonical_name, type_id, id, type)
# 309  (concept_name, alter_names, canonical_name, type_id, id, type)
# 310  (concept_name, alter_names, canonical_name, type_id, id, type)
# 311  (concept_name, alter_names, canonical_name, type_id, id, type)
# 312  (concept_name, alter_names, canonical_name, type_id, id, type)
# 313  (concept_name, alter_names, canonical_name, type_id, id, type)
# 314  (concept_name, alter_names, canonical_name, type_id, id, type)
# 315  (concept_name, alter_names, canonical_name, type_id, id, type)
# 316  (concept_name, alter_names, canonical_name, type_id, id, type)
# 317  (concept_name, alter_names, canonical_name, type_id, id, type)
# 318  (concept_name, alter_names, canonical_name, type_id, id, type)
# 319  (concept_name, alter_names, canonical_name, type_id, id, type)
# 320  (concept_name, alter_names, canonical_name, type_id, id, type)
# 321  (concept_name, alter_names, canonical_name, type_id, id, type)
# 322  (concept_name, alter_names, canonical_name, type_id, id, type)
# 323  (concept_name, alter_names, canonical_name, type_id, id, type)
# 324  (concept_name, alter_names, canonical_name, type_id, id, type)
# 325  (concept_name, alter_names, canonical_name, type_id, id, type)
# 326  (concept_name, alter_names, canonical_name, type_id, id, type)
# 327  (concept_name, alter_names, canonical_name, type_id, id, type)
# 328  (concept_name, alter_names, canonical_name, type_id, id, type)
# 329  (concept_name, alter_names, canonical_name, type_id, id, type)
# 330  (concept_name, alter_names, canonical_name, type_id, id, type)
# 331  (concept_name, alter_names, canonical_name, type_id, id, type)
# 332  (concept_name, alter_names, canonical_name, type_id, id, type)
# 333  (concept_name, alter_names, canonical_name, type_id, id, type)
# 334  (concept_name, alter_names, canonical_name, type_id, id, type)
# 335  (concept_name, alter_names, canonical_name, type_id, id, type)
# 336  (concept_name, alter_names, canonical_name, type_id, id, type)
# 337  (concept_name, alter_names, canonical_name, type_id, id, type)
# 338  (concept_name, alter_names, canonical_name, type_id, id, type)
# 339  (concept_name, alter_names, canonical_name, type_id, id, type)
# 340  (concept_name, alter_names, canonical_name, type_id, id, type)
# 341  (concept_name, alter_names, canonical_name, type_id, id, type)
# 342  (concept_name, alter_names, canonical_name, type_id, id, type)
# 343  (concept_name, alter_names, canonical_name, type_id, id, type)
# 344  (concept_name, alter_names, canonical_name, type_id, id, type)
# 345  (concept_name, alter_names, canonical_name, type_id, id, type)
# 346  (concept_name, alter_names, canonical_name, type_id, id, type)
# 347  (concept_name, alter_names, canonical_name, type_id, id, type)
# 348  (concept_name, alter_names, canonical_name, type_id, id, type)
# 349  (concept_name, alter_names, canonical_name, type_id, id, type)
# 350  (concept_name, alter_names, canonical_name, type_id, id, type)
# 351  (concept_name, alter_names, canonical_name, type_id, id, type)
# 352  (concept_name, alter_names, canonical_name, type_id, id, type)
# 353  (concept_name, alter_names, canonical_name, type_id, id, type)
# 354  (concept_name, alter_names, canonical_name, type_id, id, type)
# 355  (concept_name, alter_names, canonical_name, type_id, id, type)
# 356  (concept_name, alter_names, canonical_name, type_id, id, type)
# 357  (concept_name, alter_names, canonical_name, type_id, id, type)
# 358  (concept_name, alter_names, canonical_name, type_id, id, type)
# 359  (concept_name, alter_names, canonical_name, type_id, id, type)
# 360  (concept_name, alter_names, canonical_name, type_id, id, type)
# 361  (concept_name, alter_names, canonical_name, type_id, id, type)
# 362  (concept_name, alter_names, canonical_name, type_id, id, type)
# 363  (concept_name, alter_names, canonical_name, type_id, id, type)
# 364  (concept_name, alter_names, canonical_name, type_id, id, type)
# 365  (concept_name, alter_names, canonical_name, type_id, id, type)
# 366  (concept_name, alter_names, canonical_name, type_id, id, type)
# 367  (concept_name, alter_names, canonical_name, type_id, id, type)
# 368  (concept_name, alter_names, canonical_name, type_id, id, type)
# 369  (concept_name, alter_names, canonical_name, type_id, id, type)
# 370  (concept_name, alter_names, canonical_name, type_id, id, type)
# 371  (concept_name, alter_names, canonical_name, type_id, id, type)
# 372  (concept_name, alter_names, canonical_name, type_id, id, type)
# 373  (concept_name, alter_names, canonical_name, type_id, id, type)
# 374  (concept_name, alter_names, canonical_name, type_id, id, type)
# 375  (concept_name, alter_names, canonical_name, type_id, id, type)
# 376  (concept_name, alter_names, canonical_name, type_id, id, type)
# 377  (concept_name, alter_names, canonical_name, type_id, id, type)
# 378  (concept_name, alter_names, canonical_name, type_id, id, type)
# 379  (concept_name, alter_names, canonical_name, type_id, id, type)
# 380  (concept_name, alter_names, canonical_name, type_id, id, type)
# 381  (concept_name, alter_names, canonical_name, type_id, id, type)
# 382  (concept_name, alter_names, canonical_name, type_id, id, type)
# 383  (concept_name, alter_names, canonical_name, type_id, id, type)
# 384  (concept_name, alter_names, canonical_name, type_id, id, type)
# 385  (concept_name, alter_names, canonical_name, type_id, id, type)
# 386  (concept_name, alter_names, canonical_name, type_id, id, type)
# 387  (concept_name, alter_names, canonical_name, type_id, id, type)
# 388  (concept_name, alter_names, canonical_name, type_id, id, type)
# 389  (concept_name, alter_names, canonical_name, type_id, id, type)
# 390  (concept_name, alter_names, canonical_name, type_id, id, type)
# 391  (concept_name, alter_names, canonical_name, type_id, id, type)
# 392  (concept_name, alter_names, canonical_name, type_id, id, type)
# 393  (concept_name, alter_names, canonical_name, type_id, id, type)
# 394  (concept_name, alter_names, canonical_name, type_id, id, type)
# 395  (concept_name, alter_names, canonical_name, type_id, id, type)
# 396  (concept_name, alter_names, canonical_name, type_id, id, type)
# 397  (concept_name, alter_names, canonical_name, type_id, id, type)
# 398  (concept_name, alter_names, canonical_name, type_id, id, type)
# 399  (concept_name, alter_names, canonical_name, type_id, id, type)
# 400  (concept_name, alter_names, canonical_name, type_id, id, type)
# 401  (concept_name, alter_names, canonical_name, type_id, id, type)
# 402  (concept_name, alter_names, canonical_name, type_id, id, type)
# 403  (concept_name, alter_names, canonical_name, type_id, id, type)
# 404  (concept_name, alter_names, canonical_name, type_id, id, type)
# 405  (concept_name, alter_names, canonical_name, type_id, id, type)
# 406  (concept_name, alter_names, canonical_name, type_id, id, type)
# 407  (concept_name, alter_names, canonical_name, type_id, id, type)
# 408  (concept_name, alter_names, canonical_name, type_id, id, type)
# 409  (concept_name, alter_names, canonical_name, type_id, id, type)
# 410  (concept_name, alter_names, canonical_name, type_id, id, type)
# 411  (concept_name, alter_names, canonical_name, type_id, id, type)
# 412  (concept_name, alter_names, canonical_name, type_id, id, type)
# 413  (concept_name, alter_names, canonical_name, type_id, id, type)
# 414  (concept_name, alter_names, canonical_name, type_id, id, type)
# 415  (concept_name, alter_names, canonical_name, type_id, id, type)
# 416  (concept_name, alter_names, canonical_name, type_id, id, type)
# 417  (concept_name, alter_names, canonical_name, type_id, id, type)
# 418  (concept_name, alter_names, canonical_name, type_id, id, type)
# 419  (concept_name, alter_names, canonical_name, type_id, id, type)
# 420  (concept_name, alter_names, canonical_name, type_id, id, type)
# 421  (concept_name, alter_names, canonical_name, type_id, id, type)
# 422  (concept_name, alter_names, canonical_name, type_id, id, type)
# 423  (concept_name, alter_names, canonical_name, type_id, id, type)
# 424  (concept_name, alter_names, canonical_name, type_id, id, type)
# 425  (concept_name, alter_names, canonical_name, type_id, id, type)
# 426  (concept_name, alter_names, canonical_name, type_id, id, type)
# 427  (concept_name, alter_names, canonical_name, type_id, id, type)
# 428  (concept_name, alter_names, canonical_name, type_id, id, type)
# 429  (concept_name, alter_names, canonical_name, type_id, id, type)
# 430  (concept_name, alter_names, canonical_name, type_id, id, type)
# 431  (concept_name, alter_names, canonical_name, type_id, id, type)
# 432  (concept_name, alter_names, canonical_name, type_id, id, type)
# 433  (concept_name, alter_names, canonical_name, type_id, id, type)
# 434  (concept_name, alter_names, canonical_name, type_id, id, type)
# 435  (concept_name, alter_names, canonical_name, type_id, id, type)
# 436  (concept_name, alter_names, canonical_name, type_id, id, type)
# 437  (concept_name, alter_names, canonical_name, type_id, id, type)
# 438  (concept_name, alter_names, canonical_name, type_id, id, type)
# 439  (concept_name, alter_names, canonical_name, type_id, id, type)
# 440  (concept_name, alter_names, canonical_name, type_id, id, type)
# 441  (concept_name, alter_names, canonical_name, type_id, id, type)
# 442  (concept_name, alter_names, canonical_name, type_id, id, type)
# 443  (concept_name, alter_names, canonical_name, type_id, id, type)
# 444  (concept_name, alter_names, canonical_name, type_id, id, type)
# 445  (concept_name, alter_names, canonical_name, type_id, id, type)
# 446  (concept_name, alter_names, canonical_name, type_id, id, type)
# 447  (concept_name, alter_names, canonical_name, type_id, id, type)
# 448  (concept_name, alter_names, canonical_name, type_id, id, type)
# 449  (concept_name, alter_names, canonical_name, type_id, id, type)
# 450  (concept_name, alter_names, canonical_name, type_id, id, type)
# 451  (concept_name, alter_names, canonical_name, type_id, id, type)
# 452  (concept_name, alter_names, canonical_name, type_id, id, type)
# 453  (concept_name, alter_names, canonical_name, type_id, id, type)
# 454  (concept_name, alter_names, canonical_name, type_id, id, type)
# 455  (concept_name, alter_names, canonical_name, type_id, id, type)
# 456  (concept_name, alter_names, canonical_name, type_id, id, type)
# 457  (concept_name, alter_names, canonical_name, type_id, id, type)
# 458  (concept_name, alter_names, canonical_name, type_id, id, type)
# 459  (concept_name, alter_names, canonical_name, type_id, id, type)
# 460  (concept_name, alter_names, canonical_name, type_id, id, type)
# 461  (concept_name, alter_names, canonical_name, type_id, id, type)
# 462  (concept_name, alter_names, canonical_name, type_id, id, type)
# 463  (concept_name, alter_names, canonical_name, type_id, id, type)
# 464  (concept_name, alter_names, canonical_name, type_id, id, type)
# 465  (concept_name, alter_names, canonical_name, type_id, id, type)
# 466  (concept_name, alter_names, canonical_name, type_id, id, type)
# 467  (concept_name, alter_names, canonical_name, type_id, id, type)
# 468  (concept_name, alter_names, canonical_name, type_id, id, type)
# 469  (concept_name, alter_names, canonical_name, type_id, id, type)
# 470  (concept_name, alter_names, canonical_name, type_id, id, type)
# 471  (concept_name, alter_names, canonical_name, type_id, id, type)
# 472  (concept_name, alter_names, canonical_name, type_id, id, type)
# 473  (concept_name, alter_names, canonical_name, type_id, id, type)
# 474  (concept_name, alter_names, canonical_name, type_id, id, type)
# 475  (concept_name, alter_names, canonical_name, type_id, id, type)
# 476  (concept_name, alter_names, canonical_name, type_id, id, type)
# 477  (concept_name, alter_names, canonical_name, type_id, id, type)
# 478  (concept_name, alter_names, canonical_name, type_id, id, type)
# 479  (concept_name, alter_names, canonical_name, type_id, id, type)
# 480  (concept_name, alter_names, canonical_name, type_id, id, type)
# 481  (concept_name, alter_names, canonical_name, type_id, id, type)
# 482  (concept_name, alter_names, canonical_name, type_id, id, type)
# 483  (concept_name, alter_names, canonical_name, type_id, id, type)
# 484  (concept_name, alter_names, canonical_name, type_id, id, type)
# 485  (concept_name, alter_names, canonical_name, type_id, id, type)
# 486  (concept_name, alter_names, canonical_name, type_id, id, type)
# 487  (concept_name, alter_names, canonical_name, type_id, id, type)
# 488  (concept_name, alter_names, canonical_name, type_id, id, type)
# 489  (concept_name, alter_names, canonical_name, type_id, id, type)
# 490  (concept_name, alter_names, canonical_name, type_id, id, type)
# 491  (concept_name, alter_names, canonical_name, type_id, id, type)
# 492  (concept_name, alter_names, canonical_name, type_id, id, type)
# 493  (concept_name, alter_names, canonical_name, type_id, id, type)
# 494  (concept_name, alter_names, canonical_name, type_id, id, type)
# 495  (concept_name, alter_names, canonical_name, type_id, id, type)
# 496  (concept_name, alter_names, canonical_name, type_id, id, type)
# 497  (concept_name, alter_names, canonical_name, type_id, id, type)
# 498  (concept_name, alter_names, canonical_name, type_id, id, type)
# 499  (concept_name, alter_names, canonical_name, type_id, id, type)
# 500  (concept_name, alter_names, canonical_name, type_id, id, type)
# 501  (concept_name, alter_names, canonical_name, type_id, id, type)
# 502  (concept_name, alter_names, canonical_name, type_id, id, type)
# 503  (concept_name, alter_names, canonical_name, type_id, id, type)
# 504  (concept_name, alter_names, canonical_name, type_id, id, type)
# 505  (concept_name, alter_names, canonical_name, type_id, id, type)
# 506  (concept_name, alter_names, canonical_name, type_id, id, type)
# 507  (concept_name, alter_names, canonical_name, type_id, id, type)
# 508  (concept_name, alter_names, canonical_name, type_id, id, type)
# 509  (concept_name, alter_names, canonical_name, type_id, id, type)
# 510  (concept_name, alter_names, canonical_name, type_id, id, type)
# 511  (concept_name, alter_names, canonical_name, type_id, id, type)
# 512  (concept_name, alter_names, canonical_name, type_id, id, type)
# 513  (concept_name, alter_names, canonical_name, type_id, id, type)
# 514  (concept_name, alter_names, canonical_name, type_id, id, type)
# 515  (concept_name, alter_names, canonical_name, type_id, id, type)
# 516  (concept_name, alter_names, canonical_name, type_id, id, type)
# 517  (concept_name, alter_names, canonical_name, type_id, id, type)
# 518  (concept_name, alter_names, canonical_name, type_id, id, type)
# 519  (concept_name, alter_names, canonical_name, type_id, id, type)
# 520  (concept_name, alter_names, canonical_name, type_id, id, type)
# 521  (concept_name, alter_names, canonical_name, type_id, id, type)
# 522  (concept_name, alter_names, canonical_name, type_id, id, type)
# 523  (concept_name, alter_names, canonical_name, type_id, id, type)
# 524  (concept_name, alter_names, canonical_name, type_id, id, type)
# 525  (concept_name, alter_names, canonical_name, type_id, id, type)
# 526  (concept_name, alter_names, canonical_name, type_id, id, type)
# 527  (concept_name, alter_names, canonical_name, type_id, id, type)
# 528  (concept_name, alter_names, canonical_name, type_id, id, type)
# 529  (concept_name, alter_names, canonical_name, type_id, id, type)
# 530  (concept_name, alter_names, canonical_name, type_id, id, type)
# 531  (concept_name, alter_names, canonical_name, type_id, id, type)
# 532  (concept_name, alter_names, canonical_name, type_id, id, type)
# 533  (concept_name, alter_names, canonical_name, type_id, id, type)
# 534  (concept_name, alter_names, canonical_name, type_id, id, type)
# 535  (concept_name, alter_names, canonical_name, type_id, id, type)
# 536  (concept_name, alter_names, canonical_name, type_id, id, type)
# 537  (concept_name, alter_names, canonical_name, type_id, id, type)
# 538  (concept_name, alter_names, canonical_name, type_id, id, type)
# 539  (concept_name, alter_names, canonical_name, type_id, id, type)
# 540  (concept_name, alter_names, canonical_name, type_id, id, type)
# 541  (concept_name, alter_names, canonical_name, type_id, id, type)
# 542  (concept_name, alter_names, canonical_name, type_id, id, type)
# 543  (concept_name, alter_names, canonical_name, type_id, id, type)
# 544  (concept_name, alter_names, canonical_name, type_id, id, type)
# 545  (concept_name, alter_names, canonical_name, type_id, id, type)
# 546  (concept_name, alter_names, canonical_name, type_id, id, type)
# 547  (concept_name, alter_names, canonical_name, type_id, id, type)
# 548  (concept_name, alter_names, canonical_name, type_id, id, type)
# 549  (concept_name, alter_names, canonical_name, type_id, id, type)
# 550  (concept_name, alter_names, canonical_name, type_id, id, type)
# 551  (concept_name, alter_names, canonical_name, type_id, id, type)
# 552  (concept_name, alter_names, canonical_name, type_id, id, type)
# 553  (concept_name, alter_names, canonical_name, type_id, id, type)
# 554  (concept_name, alter_names, canonical_name, type_id, id, type)
# 555  (concept_name, alter_names, canonical_name, type_id, id, type)
# 556  (concept_name, alter_names, canonical_name, type_id, id, type)
# 557  (concept_name, alter_names, canonical_name, type_id, id, type)
# 558  (concept_name, alter_names, canonical_name, type_id, id, type)
# 559  (concept_name, alter_names, canonical_name, type_id, id, type)
# 560  (concept_name, alter_names, canonical_name, type_id, id, type)
# 561  (concept_name, alter_names, canonical_name, type_id, id, type)
# 562  (concept_name, alter_names, canonical_name, type_id, id, type)
# 563  (concept_name, alter_names, canonical_name, type_id, id, type)
# 564  (concept_name, alter_names, canonical_name, type_id, id, type)
# 565  (concept_name, alter_names, canonical_name, type_id, id, type)
# 566  (concept_name, alter_names, canonical_name, type_id, id, type)
# 567  (concept_name, alter_names, canonical_name, type_id, id, type)
# 568  (concept_name, alter_names, canonical_name, type_id, id, type)
# 569  (concept_name, alter_names, canonical_name, type_id, id, type)
# 570  (concept_name, alter_names, canonical_name, type_id, id, type)
# 571  (concept_name, alter_names, canonical_name, type_id, id, type)
# 572  (concept_name, alter_names, canonical_name, type_id, id, type)
# 573  (concept_name, alter_names, canonical_name, type_id, id, type)
# 574  (concept_name, alter_names, canonical_name, type_id, id, type)
# 575  (concept_name, alter_names, canonical_name, type_id, id, type)
# 576  (concept_name, alter_names, canonical_name, type_id, id, type)
# 577  (concept_name, alter_names, canonical_name, type_id, id, type)
# 578  (concept_name, alter_names, canonical_name, type_id, id, type)
# 579  (concept_name, alter_names, canonical_name, type_id, id, type)
# 580  (concept_name, alter_names, canonical_name, type_id, id, type)
# 581  (concept_name, alter_names, canonical_name, type_id, id, type)
# 582  (concept_name, alter_names, canonical_name, type_id, id, type)
# 583  (concept_name, alter_names, canonical_name, type_id, id, type)
# 584  (concept_name, alter_names, canonical_name, type_id, id, type)
# 585  (concept_name, alter_names, canonical_name, type_id, id, type)
# 586  (concept_name, alter_names, canonical_name, type_id, id, type)
# 587  (concept_name, alter_names, canonical_name, type_id, id, type)
# 588  (concept_name, alter_names, canonical_name, type_id, id, type)
# 589  (concept_name, alter_names, canonical_name, type_id, id, type)
# 590  (concept_name, alter_names, canonical_name, type_id, id, type)
# 591  (concept_name, alter_names, canonical_name, type_id, id, type)
# 592  (concept_name, alter_names, canonical_name, type_id, id, type)
# 593  (concept_name, alter_names, canonical_name, type_id, id, type)
# 594  (concept_name, alter_names, canonical_name, type_id, id, type)
# 595  (concept_name, alter_names, canonical_name, type_id, id, type)
# 596  (concept_name, alter_names, canonical_name, type_id, id, type)
# 597  (concept_name, alter_names, canonical_name, type_id, id, type)
# 598  (concept_name, alter_names, canonical_name, type_id, id, type)
# 599  (concept_name, alter_names, canonical_name, type_id, id, type)
# 600  (concept_name, alter_names, canonical_name, type_id, id, type)
# 601  (concept_name, alter_names, canonical_name, type_id, id, type)
# 602  (concept_name, alter_names, canonical_name, type_id, id, type)
# 603  (concept_name, alter_names, canonical_name, type_id, id, type)
# 604  (concept_name, alter_names, canonical_name, type_id, id, type)
# 605  (concept_name, alter_names, canonical_name, type_id, id, type)
# 606  (concept_name, alter_names, canonical_name, type_id, id, type)
# 607  (concept_name, alter_names, canonical_name, type_id, id, type)
# 608  (concept_name, alter_names, canonical_name, type_id, id, type)
# 609  (concept_name, alter_names, canonical_name, type_id, id, type)
# 610  (concept_name, alter_names, canonical_name, type_id, id, type)
# 611  (concept_name, alter_names, canonical_name, type_id, id, type)
# 612  (concept_name, alter_names, canonical_name, type_id, id, type)
# 613  (concept_name, alter_names, canonical_name, type_id, id, type)
# 614  (concept_name, alter_names, canonical_name, type_id, id, type)
# 615  (concept_name, alter_names, canonical_name, type_id, id, type)
# 616  (concept_name, alter_names, canonical_name, type_id, id, type)
# 617  (concept_name, alter_names, canonical_name, type_id, id, type)
# 618  (concept_name, alter_names, canonical_name, type_id, id, type)
# 619  (concept_name, alter_names, canonical_name, type_id, id, type)
# 620  (concept_name, alter_names, canonical_name, type_id, id, type)
# 621  (concept_name, alter_names, canonical_name, type_id, id, type)
# 622  (concept_name, alter_names, canonical_name, type_id, id, type)
# 623  (concept_name, alter_names, canonical_name, type_id, id, type)
# 624  (concept_name, alter_names, canonical_name, type_id, id, type)
# 625  (concept_name, alter_names, canonical_name, type_id, id, type)
# 626  (concept_name, alter_names, canonical_name, type_id, id, type)
# 627  (concept_name, alter_names, canonical_name, type_id, id, type)
# 628  (concept_name, alter_names, canonical_name, type_id, id, type)
# 629  (concept_name, alter_names, canonical_name, type_id, id, type)
# 630  (concept_name, alter_names, canonical_name, type_id, id, type)
# 631  (concept_name, alter_names, canonical_name, type_id, id, type)
# 632  (concept_name, alter_names, canonical_name, type_id, id, type)
# 633  (concept_name, alter_names, canonical_name, type_id, id, type)
# 634  (concept_name, alter_names, canonical_name, type_id, id, type)
# 635  (concept_name, alter_names, canonical_name, type_id, id, type)
# 636  (concept_name, alter_names, canonical_name, type_id, id, type)
# 637  (concept_name, alter_names, canonical_name, type_id, id, type)

# %%
# Remove empty alter_names property from DictionaryConcept nodes
gds.run_cypher('''
                match(n:DictionaryCConcept { alter_names: "NA"}) 
                remove n.alter_names
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# link DictionaryConcept nodes to OntologicalConcept by ID
gds.run_cypher('''
                MATCH(d:DictionaryConcept), (o:OntologicalConcept)
                WHERE d.type_id = o.id
                MERGE (d)-[:IS_INSTANCE_OF]->(o)
                ''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create fulltext index on DictionaryConcept nodes
gds.run_cypher('''CREATE FULLTEXT INDEX dict_concept_search IF NOT EXISTS FOR (n:DictionaryConcept) ON EACH [n.name]''')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# (optional) Exports the whole database incl. indexes as cypher statements to the provided file
gds.run_cypher('''CALL apoc.export.cypher.all('kg_export_after_load_dictionary_concepts.cypher',{format:'cypher-shell'})''')
# Out:
#                                               file  batches  \
# 0  kg_export_after_load_dictionary_concepts.cypher        1
#
#                             source  format  nodes  relationships  properties  \
# 0  database: nodes(704), rels(683)  cypher    704            683        3960
#
#    time  rows  batchSize cypherStatements nodeStatements  \
# 0    61  1387      20000             None           None
#
#   relationshipStatements schemaStatements cleanupStatements
# 0                   None             None              None
